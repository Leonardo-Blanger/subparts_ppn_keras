# qr_codes/images/3738757335.jpg
# qr_codes/images/4949259371.jpg
# qr_codes/images/4441975297.jpg
# qr_codes/images/5093857705.jpg
# qr_codes/images/4747076605.jpg
# qr_codes/images/5036470874.jpg
# qr_codes/images/2685220165.jpg
# qr_codes/fips_all.csv
# qr_codes/fips_train.csv
# qr_codes/qr_codes_train.csv
# qr_codes/qr_codes_all.csv
# qr_codes/fips_test.csv
# qr_codes/qr_codes_test.csv
# qr_codes/qr_codes_valid.csv

# %%
from ppn_keras.networks.subparts_ssd_ppn_resnet50 import SubParts_SSD_PPN_ResNet50

network = SubParts_SSD_PPN_ResNet50(class_labels = ['qr_code'],
                                     subparts_class_labels = ['fip'],
                                     input_shape = (480,480,3))

network.model.summary()
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 480, 480, 3)  0
# __________________________________________________________________________________________________
# preprocess (Lambda)             (None, 480, 480, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 486, 486, 3)  0           preprocess[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 240, 240, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 240, 240, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 240, 240, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 242, 242, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 64) 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 120, 120, 64) 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 120, 120, 64) 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 120, 120, 64) 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 120, 120, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 120, 120, 64) 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 120, 120, 64) 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 120, 120, 256 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 120, 120, 256 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 120, 120, 256 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 120, 120, 256 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 120, 120, 256 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 120, 120, 256 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 120, 120, 64) 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 120, 120, 64) 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 120, 120, 64) 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 120, 120, 64) 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 120, 120, 64) 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 120, 120, 64) 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 120, 120, 256 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 120, 120, 256 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 120, 120, 256 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 120, 120, 256 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 120, 120, 64) 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 120, 120, 64) 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 120, 120, 64) 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 120, 120, 64) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 120, 120, 64) 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 120, 120, 64) 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 120, 120, 256 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 120, 120, 256 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 120, 120, 256 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 120, 120, 256 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 60, 60, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 60, 60, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 60, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 60, 60, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 60, 60, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 60, 60, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 60, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 60, 60, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 60, 60, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 60, 60, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 60, 60, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 60, 60, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 60, 60, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 60, 60, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 60, 60, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 60, 60, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 60, 60, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 60, 60, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 60, 60, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 60, 60, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 60, 60, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 60, 60, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 30, 30, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 30, 30, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 30, 30, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 30, 30, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 30, 30, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 30, 30, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 30, 30, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 30, 30, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 30, 30, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 30, 30, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 30, 30, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 30, 30, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 30, 30, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 30, 30, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 30, 30, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 30, 30, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 30, 30, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 30, 30, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 30, 30, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 30, 30, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 30, 30, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 30, 30, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 30, 30, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 30, 30, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_1 (MaxPooling (None, 15, 15, 256)  0           activation_30[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 30, 30, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_2 (MaxPooling (None, 8, 8, 256)    0           subparts_max_pool_1[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_3 (MaxPooling (None, 4, 4, 256)    0           subparts_max_pool_2[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_4 (MaxPooling (None, 2, 2, 256)    0           subparts_max_pool_3[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 30, 30, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_5 (MaxPooling (None, 1, 1, 256)    0           subparts_max_pool_4[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 30, 30, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# subparts_shared_conv (Conv2D)   multiple             131584      activation_30[0][0]
#                                                                  subparts_max_pool_1[0][0]
#                                                                  subparts_max_pool_2[0][0]
#                                                                  subparts_max_pool_3[0][0]
#                                                                  subparts_max_pool_4[0][0]
#                                                                  subparts_max_pool_5[0][0]
# __________________________________________________________________________________________________
# max_pool_1 (MaxPooling2D)       (None, 15, 15, 1024) 0           activation_40[0][0]
# __________________________________________________________________________________________________
# subparts_box_classifier (Conv2D multiple             55308       subparts_shared_conv[0][0]
#                                                                  subparts_shared_conv[1][0]
#                                                                  subparts_shared_conv[2][0]
#                                                                  subparts_shared_conv[3][0]
#                                                                  subparts_shared_conv[4][0]
#                                                                  subparts_shared_conv[5][0]
# __________________________________________________________________________________________________
# max_pool_2 (MaxPooling2D)       (None, 8, 8, 1024)   0           max_pool_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 30, 30, 6, 2) 0           subparts_box_classifier[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 15, 15, 6, 2) 0           subparts_box_classifier[1][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 8, 8, 6, 2)   0           subparts_box_classifier[2][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 4, 4, 6, 2)   0           subparts_box_classifier[3][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 2, 2, 6, 2)   0           subparts_box_classifier[4][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 1, 1, 6, 2)   0           subparts_box_classifier[5][0]
# __________________________________________________________________________________________________
# max_pool_3 (MaxPooling2D)       (None, 4, 4, 1024)   0           max_pool_2[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 30, 30, 6, 2) 0           reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 15, 15, 6, 2) 0           reshape_5[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 6, 2)   0           reshape_9[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 4, 4, 6, 2)   0           reshape_13[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 2, 2, 6, 2)   0           reshape_17[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 1, 1, 6, 2)   0           reshape_21[0][0]
# __________________________________________________________________________________________________
# max_pool_4 (MaxPooling2D)       (None, 2, 2, 1024)   0           max_pool_3[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 30, 30, 12)   0           activation_50[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 15, 15, 12)   0           activation_51[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 8, 8, 12)     0           activation_52[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 4, 4, 12)     0           activation_53[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 2, 2, 12)     0           activation_54[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 1, 1, 12)     0           activation_55[0][0]
# __________________________________________________________________________________________________
# subparts_box_regressor (Conv2D) multiple             110616      subparts_shared_conv[0][0]
#                                                                  subparts_shared_conv[1][0]
#                                                                  subparts_shared_conv[2][0]
#                                                                  subparts_shared_conv[3][0]
#                                                                  subparts_shared_conv[4][0]
#                                                                  subparts_shared_conv[5][0]
# __________________________________________________________________________________________________
# max_pool_5 (MaxPooling2D)       (None, 1, 1, 1024)   0           max_pool_4[0][0]
# __________________________________________________________________________________________________
# shared_conv (Conv2D)            multiple             524800      activation_40[0][0]
#                                                                  max_pool_1[0][0]
#                                                                  max_pool_2[0][0]
#                                                                  max_pool_3[0][0]
#                                                                  max_pool_4[0][0]
#                                                                  max_pool_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 30, 36)   0           reshape_2[0][0]
#                                                                  subparts_box_regressor[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 15, 15, 36)   0           reshape_6[0][0]
#                                                                  subparts_box_regressor[1][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 36)     0           reshape_10[0][0]
#                                                                  subparts_box_regressor[2][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 4, 4, 36)     0           reshape_14[0][0]
#                                                                  subparts_box_regressor[3][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 2, 2, 36)     0           reshape_18[0][0]
#                                                                  subparts_box_regressor[4][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1, 1, 36)     0           reshape_22[0][0]
#                                                                  subparts_box_regressor[5][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 30, 30, 548)  0           shared_conv[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 15, 15, 548)  0           shared_conv[1][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 548)    0           shared_conv[2][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 4, 4, 548)    0           shared_conv[3][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 2, 2, 548)    0           shared_conv[4][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 1, 1, 548)    0           shared_conv[5][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# box_classifier (Conv2D)         multiple             59196       concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  concatenate_12[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 5400, 2)      0           box_classifier[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 1350, 2)      0           box_classifier[1][0]
# __________________________________________________________________________________________________
# reshape_29 (Reshape)            (None, 384, 2)       0           box_classifier[2][0]
# __________________________________________________________________________________________________
# reshape_31 (Reshape)            (None, 96, 2)        0           box_classifier[3][0]
# __________________________________________________________________________________________________
# reshape_33 (Reshape)            (None, 24, 2)        0           box_classifier[4][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 6, 2)         0           box_classifier[5][0]
# __________________________________________________________________________________________________
# box_regressor (Conv2D)          multiple             118392      concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  concatenate_12[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 5400, 2)      0           reshape_2[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1350, 2)      0           reshape_6[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 384, 2)       0           reshape_10[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 96, 2)        0           reshape_14[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 24, 2)        0           reshape_18[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 6, 2)         0           reshape_22[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 5400, 4)      0           subparts_box_regressor[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1350, 4)      0           subparts_box_regressor[1][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 384, 4)       0           subparts_box_regressor[2][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 96, 4)        0           subparts_box_regressor[3][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 24, 4)        0           subparts_box_regressor[4][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 6, 4)         0           subparts_box_regressor[5][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 5400, 2)      0           reshape_25[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 1350, 2)      0           reshape_27[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 384, 2)       0           reshape_29[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 96, 2)        0           reshape_31[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 24, 2)        0           reshape_33[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 6, 2)         0           reshape_35[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 5400, 4)      0           box_regressor[0][0]
# __________________________________________________________________________________________________
# reshape_28 (Reshape)            (None, 1350, 4)      0           box_regressor[1][0]
# __________________________________________________________________________________________________
# reshape_30 (Reshape)            (None, 384, 4)       0           box_regressor[2][0]
# __________________________________________________________________________________________________
# reshape_32 (Reshape)            (None, 96, 4)        0           box_regressor[3][0]
# __________________________________________________________________________________________________
# reshape_34 (Reshape)            (None, 24, 4)        0           box_regressor[4][0]
# __________________________________________________________________________________________________
# reshape_36 (Reshape)            (None, 6, 4)         0           box_regressor[5][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7260, 2)      0           reshape_3[0][0]
#                                                                  reshape_7[0][0]
#                                                                  reshape_11[0][0]
#                                                                  reshape_15[0][0]
#                                                                  reshape_19[0][0]
#                                                                  reshape_23[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7260, 4)      0           reshape_4[0][0]
#                                                                  reshape_8[0][0]
#                                                                  reshape_12[0][0]
#                                                                  reshape_16[0][0]
#                                                                  reshape_20[0][0]
#                                                                  reshape_24[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 7260, 2)      0           activation_56[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 7260, 4)      0           reshape_26[0][0]
#                                                                  reshape_28[0][0]
#                                                                  reshape_30[0][0]
#                                                                  reshape_32[0][0]
#                                                                  reshape_34[0][0]
#                                                                  reshape_36[0][0]
# __________________________________________________________________________________________________
# subparts_output (Concatenate)   (None, 7260, 6)      0           concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# main_output (Concatenate)       (None, 7260, 6)      0           concatenate_15[0][0]
#                                                                  concatenate_16[0][0]
# ==================================================================================================
# Total params: 9,589,080
# Trainable params: 9,558,488
# Non-trainable params: 30,592
# __________________________________________________________________________________________________

# %%
from imgaug import augmenters as iaa
import numpy as np

# Sometimes(0.5, ...) applies the given augmenter in 50% of all cases,
# e.g. Sometimes(0.5, GaussianBlur(0.3)) would blur roughly every second
# image.
sometimes = lambda aug: iaa.Sometimes(0.5, aug)

# Define our sequence of augmentation steps that will be applied to every image.
augmentation_seq = iaa.Sequential(
    [
        #
        # Apply the following augmenters to most images.
        #
        iaa.Fliplr(0.5), # horizontally flip 50% of all images
        iaa.Flipud(0.2), # vertically flip 20% of all images

        # crop some of the images by 0-10% of their height/width
        sometimes(iaa.Crop(percent=(0, 0.1))),

        # Apply affine transformations to some of the images
        # - scale to 80-120% of image height/width (each axis independently)
        # - translate by -20 to +20 relative to height/width (per axis)
        # - rotate by -45 to +45 degrees
        # - shear by -16 to +16 degrees
        # - order: use nearest neighbour or bilinear interpolation (fast)
        # - mode: use any available mode to fill newly created pixels
        #         see API or scikit-image for which modes are available
        # - cval: if the mode is constant, then use a random brightness
        #         for the newly created pixels (e.g. sometimes black,
        #         sometimes white)
        sometimes(iaa.Affine(
            scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            rotate=(-45, 45),
            shear=(-16, 16),
            order=[0, 1],
            cval=(0, 255),
            mode=ia.ALL
        )),

        #
        # Execute 0 to 5 of the following (less important) augmenters per
        # image. Don't execute all of them, as that would often be way too
        # strong.
        #
        iaa.SomeOf((0, 5),
            [
                # Convert some images into their superpixel representation,
                # sample between 20 and 200 superpixels per image, but do
                # not replace all superpixels with their average, only
                # some of them (p_replace).
                sometimes(
                    iaa.Superpixels(
                        p_replace=(0, 1.0),
                        n_segments=(20, 200)
                    )
                ),

                # Blur each image with varying strength using
                # gaussian blur (sigma between 0 and 3.0),
                # average/uniform blur (kernel size between 2x2 and 7x7)
                # median blur (kernel size between 3x3 and 11x11).
                iaa.OneOf([
                    iaa.GaussianBlur((0, 3.0)),
                    iaa.AverageBlur(k=(2, 7)),
                    iaa.MedianBlur(k=(3, 11)),
                ]),

                # Sharpen each image, overlay the result with the original
                # image using an alpha between 0 (no sharpening) and 1
                # (full sharpening effect).
                iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)),

                # Same as sharpen, but for an embossing effect.
                iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)),

                # Search in some images either for all edges or for
                # directed edges. These edges are then marked in a black
                # and white image and overlayed with the original image
                # using an alpha of 0 to 0.7.
                sometimes(iaa.OneOf([
                    iaa.EdgeDetect(alpha=(0, 0.7)),
                    iaa.DirectedEdgeDetect(
                        alpha=(0, 0.7), direction=(0.0, 1.0)
                    ),
                ])),

                # Add gaussian noise to some images.
                # In 50% of these cases, the noise is randomly sampled per
                # channel and pixel.
                # In the other 50% of all cases it is sampled once per
                # pixel (i.e. brightness change).
                iaa.AdditiveGaussianNoise(
                    loc=0, scale=(0.0, 0.05*255), per_channel=0.5
                ),

                # Either drop randomly 1 to 10% of all pixels (i.e. set
                # them to black) or drop them on an image with 2-5% percent
                # of the original size, leading to large dropped
                # rectangles.
                iaa.OneOf([
                    iaa.Dropout((0.01, 0.1), per_channel=0.5),
                    iaa.CoarseDropout(
                        (0.03, 0.15), size_percent=(0.02, 0.05),
                        per_channel=0.2
                    ),
                ]),

                # Invert each image's chanell with 5% probability.
                # This sets each pixel value v to 255-v.
                iaa.Invert(0.05, per_channel=True), # invert color channels

                # Add a value of -10 to 10 to each pixel.
                iaa.Add((-10, 10), per_channel=0.5),

                # Change brightness of images (50-150% of original value).
                iaa.Multiply((0.5, 1.5), per_channel=0.5),

                # Improve or worsen the contrast of images.
                iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5),

                # Convert each image to grayscale and then overlay the
                # result with the original with random alpha. I.e. remove
                # colors with varying strengths.
                iaa.Grayscale(alpha=(0.0, 1.0)),

                # In some images move pixels locally around (with random
                # strengths).
                sometimes(
                    iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)
                ),

                # In some images distort local areas with varying strength.
                sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05)))
            ],
            # do all of the above augmentations in random order
            random_order=True
        )
    ],
    # do all of the above augmentations in random order
    random_order=True
)

# %%
import pandas as pd

train_qr_codes = pd.read_csv('qr_codes_train.csv', dtype={'image_id': str, 'object_id': str})
valid_qr_codes = pd.read_csv('qr_codes_valid.csv', dtype={'image_id': str, 'object_id': str})

train_fips = pd.read_csv('fips_train.csv', dtype={'image_id': str, 'object_id': str})
valid_fips = pd.read_csv('fips_valid.csv', dtype={'image_id': str, 'object_id': str})

from ppn_keras.subparts_batch_generator import SubPartsBatchGenerator

batch_generator_train = SubPartsBatchGenerator(network)
batch_generator_valid = SubPartsBatchGenerator(network)

batch_generator_train.add_data(dataset = train_qr_codes, subparts_dataset = train_fips, images_dir='images')
batch_generator_valid.add_data(dataset = valid_qr_codes, subparts_dataset = valid_fips, images_dir='images')

batch_size = 8

valid_generator, valid_size = batch_generator_valid.get_generator(batch_size = 1, shuffle = False, augmentation = False, encode_output = False)
valid_X, valid_y_subparts, valid_y_obj = [], [], []

for _ in range(valid_size):
  batch_X, batch_y = next(valid_generator)
  valid_X.append(batch_X[0])
  valid_y_subparts.append(batch_y[0][0])
  valid_y_obj.append(batch_y[1][0])
  
valid_X = np.array(valid_X)

train_generator, train_size = batch_generator_train.get_generator(batch_size=batch_size, shuffle=True, augmentation=augmentation_seq, encode_output=True)
valid_generator, valid_size = batch_generator_valid.get_generator(batch_size = batch_size, shuffle = False, augmentation = False, encode_output = True)

print('%d training images' % train_size)
print('%d validation images' % valid_size)

train_generator_vis, _ = batch_generator_train.get_generator(batch_size=1, shuffle=True, augmentation=augmentation_seq, encode_output=False)

batch_X, batch_y = next(train_generator)
print(batch_X.shape)
print(batch_y[0].shape, batch_y[1].shape)

fig = plt.figure(figsize=(20,20))

for i in range(6):
  batch_X, batch_y = next(train_generator_vis)
  img = batch_X[0]
  subpart_boxes, obj_boxes = batch_y[0][0], batch_y[1][0]
  
  img = obj_boxes.draw_on_image(img, thickness=6)
  img = subpart_boxes.draw_on_image(img, thickness=4, color=[255,0,0])
  
  ax = fig.add_subplot(3, 2, i+1)
  ax.imshow(img)
  
print(batch_y)
# Out:
# Preprocessing Dataset: 100%|██████████| 962/962 [00:34<00:00, 27.88it/s]
# Preprocessing Dataset: 100%|██████████| 143/143 [00:05<00:00, 24.66it/s]
# 567 training images
# 100 validation images
# (8, 480, 480, 3)
# (8, 7260, 6) (8, 7260, 6)
# [[BoundingBoxesOnImage([BoundingBox(x1=171.8486, y1=184.4074, x2=179.1135, y2=196.1168, label=fip), BoundingBox(x1=170.2919, y1=69.8225, x2=177.5568, y2=81.5319, label=fip), BoundingBox(x1=241.3838, y1=67.3134, x2=248.6486, y2=79.0228, label=fip)], shape=(480, 480, 3))], [BoundingBoxesOnImage([BoundingBox(x1=170.2919, y1=67.3134, x2=249.1676, y2=196.1168, label=qr_code)], shape=(480, 480, 3))]]

# %%
import keras
from ppn_keras import metrics

network.model.compile(
  optimizer = keras.optimizers.Adam(1e-4, decay=1e-4),
  loss = {'subparts_output': metrics.get_ppn_loss(), 'main_output': metrics.get_ppn_loss()},
  loss_weights = {'subparts_output': 1.0, 'main_output': 1.0}
)

# %%
from keras.callbacks import Callback, ModelCheckpoint
from ppn_keras.encode_decode_output import output_decoder
from ppn_keras.encode_decode_subparts_output import subparts_output_decoder

class PrintMetricsOnEnd(Callback):
  def __init__(self):
    super(PrintMetricsOnEnd, self).__init__()
    
  def on_epoch_end(self, epoch, logs=None):
    logs = logs or {}
    for k in self.params['metrics']:
      if k in logs:
        print('%s: %.10f' % (k, logs[k]))
    print()
    
class EvaluateValidMeanAP(Callback):
  def __init__(self):
    super(EvaluateValidMeanAP, self).__init__()
    self.best_mAP = 0
    
  def on_epoch_end(self, epoch, logs=None):
    y_pred = network.model.predict(valid_X, batch_size = batch_size, verbose = 0)
    y_pred = [
        subparts_output_decoder(y_pred[0], network, nms_threshold = 0.3),
        output_decoder(y_pred[1], network, nms_threshold = 0.3)
    ]
    
    APs = [
        metrics.AP(valid_y_subparts, y_pred[0]),
        metrics.AP(valid_y_obj, y_pred[1])
    ]
    
    print('Validation APs:', APs)
    print()
    
    if APs[1] > self.best_mAP:
      self.best_mAP = APs[1]
      network.model.save('subparts_ppn_resnet50_qr_codes_fips.%03d-%.6f_mAP.hdf5' % (epoch, APs[1]))

# !rm subparts_ppn_resnet50_qr_codes_fips.*

network.model.fit_generator(train_generator,
                            steps_per_epoch = 50,
                            epochs = 100,
                            validation_data = valid_generator,
                            validation_steps = int(np.floor(valid_size / batch_size)),
                            verbose = 1,
                            max_queue_size = 200,
                            callbacks = [
                                PrintMetricsOnEnd(),
                                EvaluateValidMeanAP()
                            ])
# Out:
# Epoch 1/100
# 50/50 [==============================] - 264s 5s/step - loss: 0.0696 - subparts_output_loss: 0.0303 - main_output_loss: 0.0393 - val_loss: 0.0118 - val_subparts_output_loss: 0.0032 - val_main_output_loss: 0.0086
- val_subparts_output_loss: 0.0018 - val_main_output_loss: 0.0012
# loss: 0.0043645872
# subparts_output_loss: 0.0022871889
# main_output_loss: 0.0020773983
# val_loss: 0.0030001891
# val_subparts_output_loss: 0.0017969972
# val_main_output_loss: 0.0012031919
#
# Validation APs: [0.0024449877750611247, 0.0721961998409057]
#
# Epoch 9/100
# 50/50 [==============================] - 106s 2s/step - loss: 0.0037 - subparts_output_loss: 0.0019 - main_output_loss: 0.0017 - val_loss: 0.0028 - val_subparts_output_loss: 0.0017 - val_main_output_loss: 0.0011
# loss: 0.0036521959
# subparts_output_loss: 0.0019307375
# main_output_loss: 0.0017214584
# val_loss: 0.0027975039
# val_subparts_output_loss: 0.0016954641
# val_main_output_loss: 0.0011020398
#
# Validation APs: [0.003667481662591687, 0.055694238683894774]
#
# Epoch 10/100
# 50/50 [==============================] - 115s 2s/step - loss: 0.0040 - subparts_output_loss: 0.0021 - main_output_loss: 0.0019 - val_loss: 0.0026 - val_subparts_output_loss: 0.0016 - val_main_output_loss: 9.9528e-04
# loss: 0.0039685863
# subparts_output_loss: 0.0020791880
# main_output_loss: 0.0018893982
# val_loss: 0.0026054560
# val_subparts_output_loss: 0.0016101731
# val_main_output_loss: 0.0009952828
#
# Validation APs: [0.004889975550122249, 0.06404865094190297]
#
# Epoch 11/100
# 50/50 [==============================] - 107s 2s/step - loss: 0.0034 - subparts_output_loss: 0.0018 - main_output_loss: 0.0015 - val_loss: 0.0024 - val_subparts_output_loss: 0.0015 - val_main_output_loss: 8.8043e-04
# loss: 0.0033735360
# subparts_output_loss: 0.0018412933
# main_output_loss: 0.0015322426
# val_loss: 0.0024197738
# val_subparts_output_loss: 0.0015393401
# val_main_output_loss: 0.0008804337
#
# Validation APs: [0.012623857933341911, 0.07782202170638214]
#
# Epoch 12/100
# 50/50 [==============================] - 115s 2s/step - loss: 0.0034 - subparts_output_loss: 0.0018 - main_output_loss: 0.0015 - val_loss: 0.0023 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 8.2846e-04
# loss: 0.0033708773
# subparts_output_loss: 0.0018475087
# main_output_loss: 0.0015233685
# val_loss: 0.0022751118
# val_subparts_output_loss: 0.0014466498
# val_main_output_loss: 0.0008284620
#
# Validation APs: [0.018795035445402192, 0.10583348797659742]
#
# Epoch 13/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.0031 - subparts_output_loss: 0.0017 - main_output_loss: 0.0013 - val_loss: 0.0021 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 7.6941e-04
# loss: 0.0030522019
# subparts_output_loss: 0.0017224322
# main_output_loss: 0.0013297696
# val_loss: 0.0021353204
# val_subparts_output_loss: 0.0013659143
# val_main_output_loss: 0.0007694060
#
# Validation APs: [0.023083136055959543, 0.08525371733131315]
#
# Epoch 14/100
# 50/50 [==============================] - 113s 2s/step - loss: 0.0033 - subparts_output_loss: 0.0017 - main_output_loss: 0.0016 - val_loss: 0.0020 - val_subparts_output_loss: 0.0013 - val_main_output_loss: 7.1463e-04
# loss: 0.0032645155
# subparts_output_loss: 0.0017143344
# main_output_loss: 0.0015501811
# val_loss: 0.0020165123
# val_subparts_output_loss: 0.0013018830
# val_main_output_loss: 0.0007146293
#
# Validation APs: [0.027851409704606603, 0.08765164252958443]
#
# Epoch 15/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.0030 - subparts_output_loss: 0.0017 - main_output_loss: 0.0014 - val_loss: 0.0019 - val_subparts_output_loss: 0.0012 - val_main_output_loss: 6.6274e-04
# loss: 0.0030367792
# subparts_output_loss: 0.0016742864
# main_output_loss: 0.0013624927
# val_loss: 0.0018962225
# val_subparts_output_loss: 0.0012334791
# val_main_output_loss: 0.0006627433
#
# Validation APs: [0.06673831464189978, 0.14245740465091694]
#
# Epoch 16/100
# 50/50 [==============================] - 105s 2s/step - loss: 0.0028 - subparts_output_loss: 0.0015 - main_output_loss: 0.0012 - val_loss: 0.0019 - val_subparts_output_loss: 0.0012 - val_main_output_loss: 6.8332e-04
# loss: 0.0027577492
# subparts_output_loss: 0.0015119338
# main_output_loss: 0.0012458154
# val_loss: 0.0018666586
# val_subparts_output_loss: 0.0011833381
# val_main_output_loss: 0.0006833205
#
# Validation APs: [0.07577118931744349, 0.20219449455112304]
#
# Epoch 17/100
# 50/50 [==============================] - 97s 2s/step - loss: 0.0027 - subparts_output_loss: 0.0015 - main_output_loss: 0.0012 - val_loss: 0.0017 - val_subparts_output_loss: 0.0011 - val_main_output_loss: 5.9609e-04
# loss: 0.0026684651
# subparts_output_loss: 0.0014903979
# main_output_loss: 0.0011780672
# val_loss: 0.0017170548
# val_subparts_output_loss: 0.0011209612
# val_main_output_loss: 0.0005960936
#
# Validation APs: [0.08743144965107327, 0.20092299632072613]
#
# Epoch 18/100
# 50/50 [==============================] - 95s 2s/step - loss: 0.0025 - subparts_output_loss: 0.0014 - main_output_loss: 0.0011 - val_loss: 0.0016 - val_subparts_output_loss: 0.0011 - val_main_output_loss: 5.6039e-04
# loss: 0.0025206582
# subparts_output_loss: 0.0013838543
# main_output_loss: 0.0011368039
# val_loss: 0.0016389523
# val_subparts_output_loss: 0.0010785641
# val_main_output_loss: 0.0005603882
#
# Validation APs: [0.11424504234964644, 0.2217967768715668]
#
# Epoch 19/100
# 50/50 [==============================] - 102s 2s/step - loss: 0.0025 - subparts_output_loss: 0.0013 - main_output_loss: 0.0012 - val_loss: 0.0016 - val_subparts_output_loss: 0.0010 - val_main_output_loss: 5.5496e-04
# loss: 0.0025050306
# subparts_output_loss: 0.0013418419
# main_output_loss: 0.0011631887
# val_loss: 0.0015933785
# val_subparts_output_loss: 0.0010384142
# val_main_output_loss: 0.0005549643
#
# Validation APs: [0.12391763750368155, 0.15393604672589864]
#
# Epoch 20/100
# 50/50 [==============================] - 103s 2s/step - loss: 0.0026 - subparts_output_loss: 0.0015 - main_output_loss: 0.0011 - val_loss: 0.0016 - val_subparts_output_loss: 0.0010 - val_main_output_loss: 5.6921e-04
# loss: 0.0026094169
# subparts_output_loss: 0.0014739320
# main_output_loss: 0.0011354849
# val_loss: 0.0015875449
# val_subparts_output_loss: 0.0010183333
# val_main_output_loss: 0.0005692116
#
# Validation APs: [0.14878916702907252, 0.17255030436933316]
#
# Epoch 21/100
# 50/50 [==============================] - 104s 2s/step - loss: 0.
# 50/50 [==============================] - 98s 2s/step - loss: 0.0019 - subparts_output_loss: 9.9080e-04 - main_output_loss: 8.9179e-04 - val_loss: 0.0010 - val_subparts_output_loss: 6.6627e-04 - val_main_output_loss: 3.4425e-04
# loss: 0.0018825936
# subparts_output_loss: 0.0009907993
# main_output_loss: 0.0008917943
# val_loss: 0.0010105238
# val_subparts_output_loss: 0.0006662734
# val_main_output_loss: 0.0003442504
#
# Validation APs: [0.2144608114765661, 0.40300863903556694]
#
# Epoch 47/100
# 50/50 [==============================] - 104s 2s/step - loss: 0.0018 - subparts_output_loss: 9.3226e-04 - main_output_loss: 8.2124e-04 - val_loss: 9.9906e-04 - val_subparts_output_loss: 6.7543e-04 - val_main_output_loss: 3.2363e-04
# loss: 0.0017535061
# subparts_output_loss: 0.0009322641
# main_output_loss: 0.0008212419
# val_loss: 0.0009990602
# val_subparts_output_loss: 0.0006754266
# val_main_output_loss: 0.0003236335
#
# Validation APs: [0.2249713408821454, 0.4630884058183353]
#
# Epoch 48/100
# 50/50 [==============================] - 96s 2s/step - loss: 0.0015 - subparts_output_loss: 8.9901e-04 - main_output_loss: 6.1713e-04 - val_loss: 9.6022e-04 - val_subparts_output_loss: 6.4127e-04 - val_main_output_loss: 3.1896e-04
# loss: 0.0015161427
# subparts_output_loss: 0.0008990092
# main_output_loss: 0.0006171335
# val_loss: 0.0009602221
# val_subparts_output_loss: 0.0006412670
# val_main_output_loss: 0.0003189551
#
# Validation APs: [0.2533246988515989, 0.5344135779028482]
#
# Epoch 49/100
# 50/50 [==============================] - 106s 2s/step - loss: 0.0017 - subparts_output_loss: 9.2946e-04 - main_output_loss: 7.6385e-04 - val_loss: 9.3563e-04 - val_subparts_output_loss: 6.4147e-04 - val_main_output_loss: 2.9417e-04
# loss: 0.0016933104
# subparts_output_loss: 0.0009294558
# main_output_loss: 0.0007638546
# val_loss: 0.0009356342
# val_subparts_output_loss: 0.0006414660
# val_main_output_loss: 0.0002941682
#
# Validation APs: [0.2647129891250104, 0.4200543208927777]
#
# Epoch 50/100
# 50/50 [==============================] - 105s 2s/step - loss: 0.0018 - subparts_output_loss: 0.0010 - main_output_loss: 7.8253e-04 - val_loss: 9.3002e-04 - val_subparts_output_loss: 6.3409e-04 - val_main_output_loss: 2.9594e-04
# loss: 0.0018181859
# subparts_output_loss: 0.0010356586
# main_output_loss: 0.0007825272
# val_loss: 0.0009300236
# val_subparts_output_loss: 0.0006340852
# val_main_output_loss: 0.0002959385
#
# Validation APs: [0.23942263226879065, 0.47856144240384413]
#
# Epoch 51/100
# 50/50 [==============================] - 96s 2s/step - loss: 0.0015 - subparts_output_loss: 8.3726e-04 - main_output_loss: 6.1353e-04 - val_loss: 9.1405e-04 - val_subparts_output_loss: 6.2762e-04 - val_main_output_loss: 2.8643e-04
# loss: 0.0014507892
# subparts_output_loss: 0.0008372609
# main_output_loss: 0.0006135283
# val_loss: 0.0009140530
# val_subparts_output_loss: 0.0006276209
# val_main_output_loss: 0.0002864320
#
# Validation APs: [0.24757278313784212, 0.4982354008312709]
#
# Epoch 52/100
# 50/50 [==============================] - 97s 2s/step - loss: 0.0016 - subparts_output_loss: 8.6527e-04 - main_output_loss: 7.1634e-04 - val_loss: 8.9570e-04 - val_subparts_output_loss: 6.1297e-04 - val_main_output_loss: 2.8273e-04
# loss: 0.0015816136
# subparts_output_loss: 0.0008652738
# main_output_loss: 0.0007163398
# val_loss: 0.0008956978
# val_subparts_output_loss: 0.0006129727
# val_main_output_loss: 0.0002827252
#
# Validation APs: [0.28632637736998934, 0.4960370684637262]
#
# Epoch 53/100
# 50/50 [==============================] - 98s 2s/step - loss: 0.0016 - subparts_output_loss: 9.1031e-04 - main_output_loss: 6.5870e-04 - val_loss: 9.1876e-04 - val_subparts_output_loss: 6.2275e-04 - val_main_output_loss: 2.9602e-04
# loss: 0.0015690076
# subparts_output_loss: 0.0009103101
# main_output_loss: 0.0006586976
# val_loss: 0.0009187639
# val_subparts_output_loss: 0.0006227466
# val_main_output_loss: 0.0002960173
#
# Validation APs: [0.30825058696927604, 0.5783194236131459]
#
# Epoch 54/100
# 50/50 [==============================] - 105s 2s/step - loss: 0.0014 - subparts_output_loss: 8.1896e-04 - main_output_loss: 5.4510e-04 - val_loss: 9.2711e-04 - val_subparts_output_loss: 6.1799e-04 - val_main_output_loss: 3.0913e-04
# loss: 0.0013640640
# subparts_output_loss: 0.0008189619
# main_output_loss: 0.0005451021
# val_loss: 0.0009271120
# val_subparts_output_loss: 0.0006179851
# val_main_output_loss: 0.0003091269
#
# Validation APs: [0.2449039139342451, 0.5346480373423985]
#
# Epoch 55/100
# 50/50 [==============================] - 116s 2s/step - loss: 0.0017 - subparts_output_loss: 0.0010 - main_output_loss: 7.0726e-04 - val_loss: 8.8956e-04 - val_subparts_output_loss: 5.9974e-04 - val_main_output_loss: 2.8982e-04
# loss: 0.0017127672
# subparts_output_loss: 0.0010055081
# main_output_loss: 0.0007072590
# val_loss: 0.0008895568
# val_subparts_output_loss: 0.0005997353
# val_main_output_loss: 0.0002898215
#
# Validation APs: [0.3082310522486885, 0.5831493788083059]
#
# Epoch 56/100
# 50/50 [==============================] - 107s 2s/step - loss: 0.0014 - subparts_output_loss: 7.6457e-04 - main_output_loss: 6.0510e-04 - val_loss: 8.9121e-04 - val_subparts_output_loss: 5.9761e-04 - val_main_output_loss: 2.9360e-04
# loss: 0.0013696746
# subparts_output_loss: 0.0007645736
# main_output_loss: 0.0006051010
# val_loss: 0.0008912082
# val_subparts_output_loss: 0.0005976128
# val_main_output_loss: 0.0002935955
#
# Validation APs: [0.2772314669814364, 0.4348240573516085]
#
# Epoch 57/100
# 50/50 [==============================] - 103s 2s/step - loss: 0.0017 - subparts_output_loss: 9.1954e-04 - main_output_loss: 7.6006e-04 - val_loss: 8.9695e-04 - val_subparts_output_loss: 6.0130e-04 - val_main_output_loss: 2.9566e-04
# loss: 0.0016796029
# subparts_output_loss: 0.0009195446
# main_output_loss: 0.0007600583
# val_loss: 0.0008969550
# val_subparts_output_loss: 0.0006012980
# val_main_output_loss: 0.0002956570
#
# Validation APs: [0.300118089019943, 0.5403478024679021]
#
# Epoch 58/100
# 50/50 [==============================] - 85s 2s/step - loss: 0.0013 - subparts_output_loss: 8.0639e-04 - main_output_loss: 5.3907e-04 - val_loss: 8.7869e-04 - val_subparts_output_loss: 5.8791e-04 - val_main_output_loss: 2.9079e-04
# loss: 0.0013454568
# subparts_output_loss: 0.0008063870
# main_output_loss: 0.0005390697
# val_loss: 0.0008786934
# val_subparts_output_loss: 0.0005879054
# val_main_output_loss: 0.0002907880
#
# Validation APs: [0.33593243385072835, 0.6264354376472996]
#
# Epoch 65/100
# 50/50 [==============================] - 96s 2s/step - loss: 0.0014 - subparts_output_loss: 8.1372e-04 - main_output_loss: 5.8283e-04 - val_loss: 8.7568e-04 - val_subparts_output_loss: 5.7932e-04 - val_main_output_loss: 2.9636e-04
# loss: 0.0013965527
# subparts_output_loss: 0.0008137222
# main_output_loss: 0.0005828306
# val_loss: 0.0008756765
# val_subparts_output_loss: 0.0005793169
# val_main_output_loss: 0.0002963595
#
# Validation APs: [0.2498055969861585, 0.6139043781592965]
#
# Epoch 66/100
# 50/50 [==============================] - 94s 2s/step - loss: 0.0014 - subparts_output_loss: 7.9556e-04 - main_output_loss: 5.9015e-04 - val_loss: 8.3192e-04 - val_subparts_output_loss: 5.7053e-04 - val_main_output_loss: 2.6140e-04
# loss: 0.0013857145
# subparts_output_loss: 0.0007955644
# main_output_loss: 0.0005901501
# val_loss: 0.0008319232
# val_subparts_output_loss: 0.0005705277
# val_main_output_loss: 0.0002613955
#
# Validation APs: [0.2959671248596528, 0.6432471944433635]
#
# Epoch 67/100
# 50/50 [==============================] - 89s 2s/step - loss: 0.0015 - subparts_output_loss: 8.8544e-04 - main_output_loss: 5.8243e-04 - val_loss: 8.6167e-04 - val_subparts_output_loss: 5.9295e-04 - val_main_output_loss: 2.6871e-04
# loss: 0.0014678683
# subparts_output_loss: 0.0008854399
# main_output_loss: 0.0005824284
# val_loss: 0.0008616671
# val_subparts_output_loss: 0.0005929535
# val_main_output_loss: 0.0002687135
#
# Validation APs: [0.26011682734024927, 0.6208625284419235]
#
# Epoch 68/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.0014 - subparts_output_loss: 8.2848e-04 - main_output_loss: 5.4934e-04 - val_loss: 8.4128e-04 - val_subparts_output_loss: 5.7929e-04 - val_main_output_loss: 2.6199e-04
# loss: 0.0013778207
# subparts_output_loss: 0.0008284798
# main_output_loss: 0.0005493409
# val_loss: 0.0008412811
# val_subparts_output_loss: 0.0005792909
# val_main_output_loss: 0.0002619903
#
# Validation APs: [0.25859551686495086, 0.6127046640823712]
#
# Epoch 69/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0015 - subparts_output_loss: 8.3666e-04 - main_output_loss: 6.2932e-04 - val_loss: 8.4741e-04 - val_subparts_output_loss: 5.7500e-04 - val_main_output_loss: 2.7241e-04
# loss: 0.0014659797
# subparts_output_loss: 0.0008366605
# main_output_loss: 0.0006293193
# val_loss: 0.0008474144
# val_subparts_output_loss: 0.0005750043
# val_main_output_loss: 0.0002724101
#
# Validation APs: [0.29020249944062826, 0.6619029858867663]
#
# Epoch 70/100
# 50/50 [==============================] - 98s 2s/step - loss: 0.0014 - subparts_output_loss: 7.4417e-04 - main_output_loss: 6.3693e-04 - val_loss: 8.7577e-04 - val_subparts_output_loss: 5.7768e-04 - val_main_output_loss: 2.9809e-04
# loss: 0.0013811044
# subparts_output_loss: 0.0007441712
# main_output_loss: 0.0006369332
# val_loss: 0.0008757679
# val_subparts_output_loss: 0.0005776759
# val_main_output_loss: 0.0002980920
#
# Validation APs: [0.3320657739368121, 0.6170242187735664]
#
# Epoch 71/100
# 50/50 [==============================] - 104s 2s/step - loss: 0.0015 - subparts_output_loss: 8.0331e-04 - main_output_loss: 6.8013e-04 - val_loss: 9.3005e-04 - val_subparts_output_loss: 6.1642e-04 - val_main_output_loss: 3.1363e-04
# loss: 0.0014834428
# subparts_output_loss: 0.0008033125
# main_output_loss: 0.0006801303
# val_loss: 0.0009300483
# val_subparts_output_loss: 0.0006164228
# val_main_output_loss: 0.0003136255
#
# Validation APs: [0.3030677274690337, 0.5844774371806957]
#
# Epoch 72/100
# 50/50 [==============================] - 96s 2s/step - loss: 0.0018 - subparts_output_loss: 9.9162e-04 - main_output_loss: 8.5097e-04 - val_loss: 9.4829e-04 - val_subparts_output_loss: 6.0646e-04 - val_main_output_loss: 3.4182e-04
# loss: 0.0018425832
# subparts_output_loss: 0.0009916175
# main_output_loss: 0.0008509657
# val_loss: 0.0009482853
# val_subparts_output_loss: 0.0006064640
# val_main_output_loss: 0.0003418213
#
# Validation APs: [0.2913999655934689, 0.5394998000758624]
#
# Epoch 73/100
# 50/50 [==============================] - 104s 2s/step - loss: 0.0014 - subparts_output_loss: 7.8405e-04 - main_output_loss: 6.0630e-04 - val_loss: 8.6980e-04 - val_subparts_output_loss: 5.7846e-04 - val_main_output_loss: 2.9134e-04
# loss: 0.0013903490
# subparts_output_loss: 0.0007840486
# main_output_loss: 0.0006063005
# val_loss: 0.0008697966
# val_subparts_output_loss: 0.0005784559
# val_main_output_loss: 0.0002913406
#
# Validation APs: [0.30656296209024353, 0.6098300501119254]
#
# Epoch 74/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.0016 - subparts_output_loss: 8.8330e-04 - main_output_loss: 6.7439e-04 - val_loss: 8.2462e-04 - val_subparts_output_loss: 5.6597e-04 - val_main_output_loss: 2.5864e-04
# loss: 0.0015576863
# subparts_output_loss: 0.0008832976
# main_output_loss: 0.0006743887
# val_loss: 0.0008246159
# val_subparts_output_loss: 0.0005659748
# val_main_output_loss: 0.0002586410
#
# Validation APs: [0.2904532200987119, 0.5664985424494318]
#
# Epoch 75/100
# 50/50 [==============================] - 99s 2s/step - loss: 0.0013 - subparts_output_loss: 7.8753e-04 - main_output_loss: 5.2983e-04 - val_loss: 8.2255e-04 - val_subparts_output_loss: 5.5584e-04 - val_main_output_loss: 2.6671e-04
# loss: 0.0013173609
# subparts_output_loss: 0.0007875289
# main_output_loss: 0.0005298320
# val_loss: 0.0008225493
# val_subparts_output_loss: 0.0005558354
# val_main_output_loss: 0.0002667139
#
# Validation APs: [0.31135851832587413, 0.6384515755056053]
#
# Epoch 76/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.
# loss: 0.0012653291
# subparts_output_loss: 0.0007609167
# main_output_loss: 0.0005044124
# val_loss: 0.0008012413
# val_subparts_output_loss: 0.0005481809
# val_main_output_loss: 0.0002530604
#
# Validation APs: [0.33949142354968626, 0.6825906671040364]
#
# Epoch 83/100
# 50/50 [==============================] - 100s 2s/step - loss: 0.0013 - subparts_output_loss: 8.0208e-04 - main_output_loss: 5.2552e-04 - val_loss: 8.2993e-04 - val_subparts_output_loss: 5.5742e-04 - val_main_output_loss: 2.7251e-04
# loss: 0.0013276008
# subparts_output_loss: 0.0008020760
# main_output_loss: 0.0005255248
# val_loss: 0.0008299269
# val_subparts_output_loss: 0.0005574186
# val_main_output_loss: 0.0002725083
#
# Validation APs: [0.29860807555166347, 0.6574484719137149]
#
# Epoch 84/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.0012 - subparts_output_loss: 6.7036e-04 - main_output_loss: 4.8885e-04 - val_loss: 8.0685e-04 - val_subparts_output_loss: 5.4298e-04 - val_main_output_loss: 2.6387e-04
# loss: 0.0011592016
# subparts_output_loss: 0.0006703564
# main_output_loss: 0.0004888451
# val_loss: 0.0008068507
# val_subparts_output_loss: 0.0005429808
# val_main_output_loss: 0.0002638700
#
# Validation APs: [0.32783877341381534, 0.699660365166813]
#
# Epoch 85/100
# 50/50 [==============================] - 105s 2s/step - loss: 0.0013 - subparts_output_loss: 7.8280e-04 - main_output_loss: 5.0169e-04 - val_loss: 7.9362e-04 - val_subparts_output_loss: 5.3540e-04 - val_main_output_loss: 2.5822e-04
# loss: 0.0012844879
# subparts_output_loss: 0.0007828000
# main_output_loss: 0.0005016879
# val_loss: 0.0007936186
# val_subparts_output_loss: 0.0005354017
# val_main_output_loss: 0.0002582169
#
# Validation APs: [0.30838154513960525, 0.7078785432619756]
#
# Epoch 86/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.0014 - subparts_output_loss: 8.0376e-04 - main_output_loss: 5.8731e-04 - val_loss: 8.1696e-04 - val_subparts_output_loss: 5.4164e-04 - val_main_output_loss: 2.7532e-04
# loss: 0.0013910752
# subparts_output_loss: 0.0008037637
# main_output_loss: 0.0005873116
# val_loss: 0.0008169588
# val_subparts_output_loss: 0.0005416398
# val_main_output_loss: 0.0002753190
#
# Validation APs: [0.3259449966173151, 0.6827207771132708]
#
# Epoch 87/100
# 50/50 [==============================] - 90s 2s/step - loss: 0.0014 - subparts_output_loss: 7.8555e-04 - main_output_loss: 5.7529e-04 - val_loss: 8.1518e-04 - val_subparts_output_loss: 5.3418e-04 - val_main_output_loss: 2.8099e-04
# loss: 0.0013608397
# subparts_output_loss: 0.0007855531
# main_output_loss: 0.0005752866
# val_loss: 0.0008151757
# val_subparts_output_loss: 0.0005341817
# val_main_output_loss: 0.0002809940
#
# Validation APs: [0.31803602173627366, 0.7250969002814704]
#
# Epoch 88/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0014 - subparts_output_loss: 7.7207e-04 - main_output_loss: 5.9811e-04 - val_loss: 8.0417e-04 - val_subparts_output_loss: 5.2975e-04 - val_main_output_loss: 2.7442e-04
# loss: 0.0013701846
# subparts_output_loss: 0.0007720746
# main_output_loss: 0.0005981100
# val_loss: 0.0008041697
# val_subparts_output_loss: 0.0005297545
# val_main_output_loss: 0.0002744152
#
# Validation APs: [0.36176245062647355, 0.6897910168598996]
#
# Epoch 89/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.0013 - subparts_output_loss: 7.3790e-04 - main_output_loss: 5.3003e-04 - val_loss: 8.2857e-04 - val_subparts_output_loss: 5.3694e-04 - val_main_output_loss: 2.9164e-04
# loss: 0.0012679301
# subparts_output_loss: 0.0007379017
# main_output_loss: 0.0005300284
# val_loss: 0.0008285741
# val_subparts_output_loss: 0.0005369363
# val_main_output_loss: 0.0002916378
#
# Validation APs: [0.3765319905363341, 0.7498067152317703]
#
# Epoch 90/100
# 50/50 [==============================] - 102s 2s/step - loss: 0.0014 - subparts_output_loss: 7.8455e-04 - main_output_loss: 5.9595e-04 - val_loss: 9.1256e-04 - val_subparts_output_loss: 5.5798e-04 - val_main_output_loss: 3.5458e-04
# loss: 0.0013805054
# subparts_output_loss: 0.0007845527
# main_output_loss: 0.0005959526
# val_loss: 0.0009125569
# val_subparts_output_loss: 0.0005579804
# val_main_output_loss: 0.0003545764
#
# Validation APs: [0.3677412164136115, 0.7305053930603786]
#
# Epoch 91/100
# 50/50 [==============================] - 102s 2s/step - loss: 0.0013 - subparts_output_loss: 7.5874e-04 - main_output_loss: 5.8413e-04 - val_loss: 7.6507e-04 - val_subparts_output_loss: 5.1652e-04 - val_main_output_loss: 2.4855e-04
# loss: 0.0013428692
# subparts_output_loss: 0.0007587427
# main_output_loss: 0.0005841265
# val_loss: 0.0007650650
# val_subparts_output_loss: 0.0005165200
# val_main_output_loss: 0.0002485450
#
# Validation APs: [0.3400569432503945, 0.7217812723322887]
#
# Epoch 92/100
# 50/50 [==============================] - 118s 2s/step - loss: 0.0014 - subparts_output_loss: 8.0331e-04 - main_output_loss: 5.8841e-04 - val_loss: 7.9247e-04 - val_subparts_output_loss: 5.3865e-04 - val_main_output_loss: 2.5382e-04
# loss: 0.0013917208
# subparts_output_loss: 0.0008033072
# main_output_loss: 0.0005884136
# val_loss: 0.0007924669
# val_subparts_output_loss: 0.0005386471
# val_main_output_loss: 0.0002538197
#
# Validation APs: [0.32375602301685413, 0.6736302710736034]
#
# Epoch 93/100
# 50/50 [==============================] - 105s 2s/step - loss: 0.0013 - subparts_output_loss: 7.4634e-04 - main_output_loss: 5.3571e-04 - val_loss: 7.5897e-04 - val_subparts_output_loss: 5.2583e-04 - val_main_output_loss: 2.3314e-04
# loss: 0.0012820508
# subparts_output_loss: 0.0007463436
# main_output_loss: 0.0005357071
# val_loss: 0.0007589668
# val_subparts_output_loss: 0.0005258258
# val_main_output_loss: 0.0002331410
#
# Validation APs: [0.32666900940389976, 0.689615076263677]
#
# Epoch 94/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.0012 - subparts_output_loss: 7.0461e-04 - main_output_loss: 4.9596e-04 - val_loss: 7.7699e-04 - val_subparts_output_loss: 5.2692e-04 - val_main_output_loss: 2.5007e-04
# loss: 0.0012005717
# subparts_output_loss: 0.0007046126
# main_output_loss: 0.0004959591
# val_loss: 0.0007769890
# val_subparts_output_loss: 0.0005269239
# val_main_output_loss: 0.0002500651
#
# Validation APs: [0.3477133852327382, 0.6481988663571039]
#
# Epoch 95/100
# 50/50 [==============================] - 97s 2s/step - loss: 0.0012 - subparts_output_loss: 6.8674e-04 - main_output_loss: 4.7571e-04 - val_loss: 7.5993e-04 - val_subparts_output_loss: 5.2057e-04 - val_main_output_loss: 2.3936e-04
# loss: 0.0011624595
# subparts_output_loss: 0.0006867445
# main_output_loss: 0.0004757150
# val_loss: 0.0007599296
# val_subparts_output_loss: 0.0005205729
# val_main_output_loss: 0.0002393567
#
# Validation APs: [0.35481892818907257, 0.7137510921770608]
#
# Epoch 96/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.0016 - subparts_output_loss: 8.1860e-04 - main_output_loss: 7.6051e-04 - val_loss: 7.6402e-04 - val_subparts_output_loss: 5.2227e-04 - val_main_output_loss: 2.4175e-04
# loss: 0.0015791106
# subparts_output_loss: 0.0008186043
# main_output_loss: 0.0007605063
# val_loss: 0.0007640214
# val_subparts_output_loss: 0.0005222729
# val_main_output_loss: 0.0002417484
#
# Validation APs: [0.3606410167461992, 0.6850074329864524]
#
# Epoch 97/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.0013 - subparts_output_loss: 7.5088e-04 - main_output_loss: 5.1895e-04 - val_loss: 7.5225e-04 - val_subparts_output_loss: 5.0523e-04 - val_main_output_loss: 2.4701e-04
# loss: 0.0012698343
# subparts_output_loss: 0.0007508817
# main_output_loss: 0.0005189527
# val_loss: 0.0007522468
# val_subparts_output_loss: 0.0005052327
# val_main_output_loss: 0.0002470141
#
# Validation APs: [0.3782540468321879, 0.7662770442039254]
#
# Epoch 98/100
# 50/50 [==============================] - 99s 2s/step - loss: 0.0011 - subparts_output_loss: 6.6049e-04 - main_output_loss: 4.4135e-04 - val_loss: 7.4288e-04 - val_subparts_output_loss: 5.0178e-04 - val_main_output_loss: 2.4110e-04
# loss: 0.0011018380
# subparts_output_loss: 0.0006604912
# main_output_loss: 0.0004413468
# val_loss: 0.0007428821
# val_subparts_output_loss: 0.0005017798
# val_main_output_loss: 0.0002411024
#
# Validation APs: [0.3699059070982893, 0.7224491818588727]
#
# Epoch 99/100
# 50/50 [==============================] - 94s 2s/step - loss: 0.0013 - subparts_output_loss: 7.4721e-04 - main_output_loss: 5.6663e-04 - val_loss: 7.4731e-04 - val_subparts_output_loss: 4.9667e-04 - val_main_output_loss: 2.5064e-04
# loss: 0.0013138385
# subparts_output_loss: 0.0007472082
# main_output_loss: 0.0005666303
# val_loss: 0.0007473082
# val_subparts_output_loss: 0.0004966692
# val_main_output_loss: 0.0002506390
#
# Validation APs: [0.3915193746803406, 0.7336640282174158]
#
# Epoch 100/100
# 50/50 [==============================] - 100s 2s/step - loss: 0.0014 - subparts_output_loss: 7.6745e-04 - main_output_loss: 5.8602e-04 - val_loss: 7.7224e-04 - val_subparts_output_loss: 5.0438e-04 - val_main_output_loss: 2.6786e-04
# loss: 0.0013534683
# subparts_output_loss: 0.0007674450
# main_output_loss: 0.0005860233
# val_loss: 0.0007722374
# val_subparts_output_loss: 0.0005043820
# val_main_output_loss: 0.0002678554
#
# Validation APs: [0.34818238508862764, 0.7229760939600667]

# %%
# !ls -l
# Out:
# total 3465496
# -rw-r--r-- 1 root root     19652 Jan 24 15:21 fips_test.csv
# -rw-r--r-- 1 root root    124866 Jan 24 15:21 fips_train.csv
# -rw-r--r-- 1 root root     18679 Jan 24 15:21 fips_valid.csv
# drwxr-xr-x 2 root root     36864 Jan 24 15:21 images
# drwx------ 8 root root      4096 Jan 24 15:21 ppn_keras
# -rw-r--r-- 1 root root  40509440 Jan 24 14:31 qr_code_fip_valid_subparts_resnet50.tar.gz
# -rw-r--r-- 1 root root      7819 Jan 24 15:21 qr_codes_test.csv
# -rw-r--r-- 1 root root     47591 Jan 24 15:21 qr_codes_train.csv
# -rw-r--r-- 1 root root      7135 Jan 24 15:21 qr_codes_valid.csv
# -rw-r--r-- 1 root root  40550400 Jan 24 14:32 qr_code_test_subparts_resnet50.tar.gz
# drwxr-xr-x 1 root root      4096 Jan  8 17:15 sample_data
# -rw-r--r-- 1 root root 115572840 Jan 24 15:29 subparts_ppn_resnet50_qr_codes_fips.001-0.011409_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:31 subparts_ppn_resnet50_qr_codes_fips.002-0.014328_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:33 subparts_ppn_resnet50_qr_codes_fips.003-0.019650_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:38 subparts_ppn_resnet50_qr_codes_fips.006-0.061150_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:40 subparts_ppn_resnet50_qr_codes_fips.007-0.072196_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:46 subparts_ppn_resnet50_qr_codes_fips.010-0.077822_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:48 subparts_ppn_resnet50_qr_codes_fips.011-0.105833_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:53 subparts_ppn_resnet50_qr_codes_fips.014-0.142457_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:55 subparts_ppn_resnet50_qr_codes_fips.015-0.202194_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 15:59 subparts_ppn_resnet50_qr_codes_fips.017-0.221797_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:04 subparts_ppn_resnet50_qr_codes_fips.020-0.239701_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:06 subparts_ppn_resnet50_qr_codes_fips.021-0.260335_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:17 subparts_ppn_resnet50_qr_codes_fips.027-0.328622_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:24 subparts_ppn_resnet50_qr_codes_fips.031-0.375342_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:27 subparts_ppn_resnet50_qr_codes_fips.033-0.414428_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:36 subparts_ppn_resnet50_qr_codes_fips.038-0.478241_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:46 subparts_ppn_resnet50_qr_codes_fips.044-0.484799_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 16:52 subparts_ppn_resnet50_qr_codes_fips.047-0.534414_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:00 subparts_ppn_resnet50_qr_codes_fips.052-0.578319_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:04 subparts_ppn_resnet50_qr_codes_fips.054-0.583149_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:11 subparts_ppn_resnet50_qr_codes_fips.058-0.609971_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:20 subparts_ppn_resnet50_qr_codes_fips.063-0.626435_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:23 subparts_ppn_resnet50_qr_codes_fips.065-0.643247_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:29 subparts_ppn_resnet50_qr_codes_fips.068-0.661903_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:48 subparts_ppn_resnet50_qr_codes_fips.079-0.691692_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:55 subparts_ppn_resnet50_qr_codes_fips.083-0.699660_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 17:57 subparts_ppn_resnet50_qr_codes_fips.084-0.707879_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 18:01 subparts_ppn_resnet50_qr_codes_fips.086-0.725097_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 18:04 subparts_ppn_resnet50_qr_codes_fips.088-0.749807_mAP.hdf5
# -rw-r--r-- 1 root root 115572840 Jan 24 18:19 subparts_ppn_resnet50_qr_codes_fips.096-0.766277_mAP.hdf5
# drwxr-xr-x 2 root root      4096 Jan 24 14:32 test_results
# drwxr-xr-x 2 root root      4096 Jan 24 14:31 valid_results

# %%
from ppn_keras.encode_decode_output import output_decoder
from ppn_keras.encode_decode_subparts_output import subparts_output_decoder
from google.colab import files

from glob import glob
model_path = sorted(glob('subparts_ppn_resnet50_qr_codes_fips.*'))[-1]
print(model_path)

import keras
from keras.utils.generic_utils import CustomObjectScope

with CustomObjectScope({'resnet50': keras.applications.resnet50,
                        'relu6': keras.layers.ReLU(6.),
                        'ppn_loss': metrics.get_ppn_loss()}):
    model = keras.models.load_model(model_path)

#model = network.model

y_pred = model.predict(valid_X, batch_size = batch_size)
y_pred = [
    subparts_output_decoder(y_pred[0], network, nms_threshold = 0.3),
    output_decoder(y_pred[1], network, nms_threshold = 0.3)
]

APs = [
    metrics.AP(valid_y_subparts, y_pred[0]),
    metrics.AP(valid_y_obj, y_pred[1])
]

print('Validation APs:', APs)

for i in range(valid_size):
  img, subpart_boxes, obj_boxes = valid_X[i], y_pred[0][i], y_pred[1][i]

  img = obj_boxes.draw_on_image(img, thickness=6)
  img = subpart_boxes.draw_on_image(img, thickness=4, color=[255,0,0])
  
  cv.imwrite('qr_code_fip_valid_%d.png'%i, img[..., [2,1,0]])
  
# !rm qr_code_fip_valid_subparts_resnet50.tar.gz valid_results/*
# !mkdir valid_results
# !mv qr_code_fip_valid* valid_results
# !tar -cvf qr_code_fip_valid_subparts_resnet50.tar.gz valid_results
# Out:
# subparts_ppn_resnet50_qr_codes_fips.096-0.766277_mAP.hdf5
# Validation APs: [0.3782540468321879, 0.7662770442039254]
# mkdir: cannot create directory ‘valid_results’: File exists
# valid_results/
# valid_results/qr_code_fip_valid_29.png
# valid_results/qr_code_fip_valid_96.png
# valid_results/qr_code_fip_valid_14.png
# valid_results/qr_code_fip_valid_99.png
# valid_results/qr_code_fip_valid_36.png
# valid_results/qr_code_fip_valid_76.png
# valid_results/qr_code_fip_valid_3.png
# valid_results/qr_code_fip_valid_37.png
# valid_results/qr_code_fip_valid_9.png
# valid_results/qr_code_fip_valid_86.png
# valid_results/qr_code_fip_valid_88.png
# valid_results/qr_code_fip_valid_55.png
# valid_results/qr_code_fip_valid_10.png
# valid_results/qr_code_fip_valid_40.png
# valid_results/qr_code_fip_valid_34.png
# valid_results/qr_code_fip_valid_39.png
# valid_results/qr_code_fip_valid_64.png
# valid_results/qr_code_fip_valid_63.png
# valid_results/qr_code_fip_valid_80.png
# valid_results/qr_code_fip_valid_53.png
# valid_results/qr_code_fip_valid_89.png
# valid_results/qr_code_fip_valid_25.png
# valid_results/qr_code_fip_valid_57.png
# valid_results/qr_code_fip_valid_91.png
# valid_results/qr_code_fip_valid_23.png
# valid_results/qr_code_fip_valid_49.png
# valid_results/qr_code_fip_valid_54.png
# valid_results/qr_code_fip_valid_32.png
# valid_results/qr_code_fip_valid_98.png
# valid_results/qr_code_fip_valid_69.png
# valid_results/qr_code_fip_valid_84.png
# valid_results/qr_code_fip_valid_83.png
# valid_results/qr_code_fip_valid_94.png
# valid_results/qr_code_fip_valid_24.png
# valid_results/qr_code_fip_valid_48.png
# valid_results/qr_code_fip_valid_26.png
# valid_results/qr_code_fip_valid_52.png
# valid_results/qr_code_fip_valid_45.png
# valid_results/qr_code_fip_valid_15.png
# valid_results/qr_code_fip_valid_11.png
# valid_results/qr_code_fip_valid_58.png
# valid_results/qr_code_fip_valid_77.png
# valid_results/qr_code_fip_valid_35.png
# valid_results/qr_code_fip_valid_13.png
# valid_results/qr_code_fip_valid_90.png
# valid_results/qr_code_fip_valid_27.png
# valid_results/qr_code_fip_valid_2.png
# valid_results/qr_code_fip_valid_85.png
# valid_results/qr_code_fip_valid_19.png
# valid_results/qr_code_fip_valid_97.png
# valid_results/qr_code_fip_valid_75.png
# valid_results/qr_code_fip_valid_31.png
# valid_results/qr_code_fip_valid_47.png
# valid_results/qr_code_fip_valid_60.png
# valid_results/qr_code_fip_valid_73.png
# valid_results/qr_code_fip_valid_72.png
# valid_results/qr_code_fip_valid_22.png
# valid_results/qr_code_fip_valid_70.png
# valid_results/qr_code_fip_valid_71.png
# valid_results/qr_code_fip_valid_43.png
# valid_results/qr_code_fip_valid_4.png
# valid_results/qr_code_fip_valid_78.png
# valid_results/qr_code_fip_valid_20.png
# valid_results/qr_code_fip_valid_21.png
# valid_results/qr_code_fip_valid_56.png
# valid_results/qr_code_fip_valid_12.png
# valid_results/qr_code_fip_valid_0.png
# valid_results/qr_code_fip_valid_8.png
# valid_results/qr_code_fip_valid_38.png
# valid_results/qr_code_fip_valid_66.png
# valid_results/qr_code_fip_valid_41.png
# valid_results/qr_code_fip_valid_17.png
# valid_results/qr_code_fip_valid_42.png
# valid_results/qr_code_fip_valid_67.png
# valid_results/qr_code_fip_valid_61.png
# valid_results/qr_code_fip_valid_92.png
# valid_results/qr_code_fip_valid_46.png
# valid_results/qr_code_fip_valid_30.png
# valid_results/qr_code_fip_valid_51.png
# valid_results/qr_code_fip_valid_82.png
# valid_results/qr_code_fip_valid_59.png
# valid_results/qr_code_fip_valid_50.png
# valid_results/qr_code_fip_valid_1.png
# valid_results/qr_code_fip_valid_95.png
# valid_results/qr_code_fip_valid_74.png
# valid_results/qr_code_fip_valid_44.png
# valid_results/qr_code_fip_valid_5.png
# valid_results/qr_code_fip_valid_87.png
# valid_results/qr_code_fip_valid_81.png
# valid_results/qr_code_fip_valid_7.png
# valid_results/qr_code_fip_valid_93.png
# valid_results/qr_code_fip_valid_79.png
# valid_results/qr_code_fip_valid_65.png
# valid_results/qr_code_fip_valid_18.png
# valid_results/qr_code_fip_valid_28.png
# valid_results/qr_code_fip_valid_62.png
# valid_results/qr_code_fip_valid_6.png
# valid_results/qr_code_fip_valid_16.png
# valid_results/qr_code_fip_valid_68.png
# valid_results/qr_code_fip_valid_33.png

# %%
test_qr_codes = pd.read_csv('qr_codes_test.csv', dtype={'image_id': str, 'object_id': str})
test_fips = pd.read_csv('fips_test.csv', dtype={'image_id': str, 'object_id': str})

batch_generator_test = SubPartsBatchGenerator(network)
batch_generator_test.add_data(dataset = test_qr_codes, subparts_dataset = test_fips, images_dir='images')

test_generator, test_size = batch_generator_test.get_generator(batch_size = 1, shuffle = False, augmentation = False, encode_output = False)
test_X, test_y_subparts, test_y_obj = [], [], []

for _ in range(test_size):
  batch_X, batch_y = next(test_generator)
  test_X.append(batch_X[0])
  test_y_subparts.append(batch_y[0][0])
  test_y_obj.append(batch_y[1][0])
  
test_X = np.array(test_X)


from ppn_keras.encode_decode_output import output_decoder
from ppn_keras.encode_decode_subparts_output import subparts_output_decoder
from google.colab import files

from glob import glob
model_path = sorted(glob('subparts_ppn_resnet50_qr_codes_fips.*'))[-1]
print(model_path)

import keras
from keras.utils.generic_utils import CustomObjectScope

with CustomObjectScope({'resnet50': keras.applications.resnet50,
                        'relu6': keras.layers.ReLU(6.),
                        'ppn_loss': metrics.get_ppn_loss()}):
    model = keras.models.load_model(model_path)

#model = network.model

y_pred = model.predict(test_X, batch_size = batch_size)
y_pred = [
    subparts_output_decoder(y_pred[0], network, nms_threshold = 0.3),
    output_decoder(y_pred[1], network, nms_threshold = 0.3)
]

APs = [
    metrics.AP(test_y_subparts, y_pred[0]),
    metrics.AP(test_y_obj, y_pred[1])
]

print('Test APs:', APs)

for i in range(test_size):
  img, subpart_boxes, obj_boxes = valid_X[i], y_pred[0][i], y_pred[1][i]

  img = obj_boxes.draw_on_image(img, thickness=6)
  img = subpart_boxes.draw_on_image(img, thickness=4, color=[255,0,0])
  
  cv.imwrite('qr_code_fip_test_%d.png'%i, img[..., [2,1,0]])
  
# !rm qr_code_test_subparts_resnet50.tar.gz test_results/*
# !mkdir test_results
# !mv qr_code_fip_test* test_results
# !tar -cvf qr_code_test_subparts_resnet50.tar.gz test_results
# Out:
# Preprocessing Dataset: 100%|██████████| 158/158 [00:05<00:00, 30.58it/s]
# subparts_ppn_resnet50_qr_codes_fips.096-0.766277_mAP.hdf5
# Test APs: [0.4079442802581904, 0.7692193145169527]
# mkdir: cannot create directory ‘test_results’: File exists
# test_results/
# test_results/qr_code_fip_test_67.png
# test_results/qr_code_fip_test_3.png
# test_results/qr_code_fip_test_12.png
# test_results/qr_code_fip_test_44.png
# test_results/qr_code_fip_test_84.png
# test_results/qr_code_fip_test_13.png
# test_results/qr_code_fip_test_39.png
# test_results/qr_code_fip_test_24.png
# test_results/qr_code_fip_test_54.png
# test_results/qr_code_fip_test_96.png
# test_results/qr_code_fip_test_94.png
# test_results/qr_code_fip_test_86.png
# test_results/qr_code_fip_test_98.png
# test_results/qr_code_fip_test_79.png
# test_results/qr_code_fip_test_9.png
# test_results/qr_code_fip_test_15.png
# test_results/qr_code_fip_test_83.png
# test_results/qr_code_fip_test_93.png
# test_results/qr_code_fip_test_37.png
# test_results/qr_code_fip_test_34.png
# test_results/qr_code_fip_test_51.png
# test_results/qr_code_fip_test_80.png
# test_results/qr_code_fip_test_60.png
# test_results/qr_code_fip_test_14.png
# test_results/qr_code_fip_test_62.png
# test_results/qr_code_fip_test_52.png
# test_results/qr_code_fip_test_70.png
# test_results/qr_code_fip_test_56.png
# test_results/qr_code_fip_test_16.png
# test_results/qr_code_fip_test_0.png
# test_results/qr_code_fip_test_71.png
# test_results/qr_code_fip_test_8.png
# test_results/qr_code_fip_test_2.png
# test_results/qr_code_fip_test_28.png
# test_results/qr_code_fip_test_36.png
# test_results/qr_code_fip_test_40.png
# test_results/qr_code_fip_test_73.png
# test_results/qr_code_fip_test_87.png
# test_results/qr_code_fip_test_85.png
# test_results/qr_code_fip_test_47.png
# test_results/qr_code_fip_test_81.png
# test_results/qr_code_fip_test_58.png
# test_results/qr_code_fip_test_82.png
# test_results/qr_code_fip_test_72.png
# test_results/qr_code_fip_test_11.png
# test_results/qr_code_fip_test_25.png
# test_results/qr_code_fip_test_61.png
# test_results/qr_code_fip_test_6.png
# test_results/qr_code_fip_test_63.png
# test_results/qr_code_fip_test_89.png
# test_results/qr_code_fip_test_91.png
# test_results/qr_code_fip_test_29.png
# test_results/qr_code_fip_test_75.png
# test_results/qr_code_fip_test_78.png
# test_results/qr_code_fip_test_65.png
# test_results/qr_code_fip_test_5.png
# test_results/qr_code_fip_test_7.png
# test_results/qr_code_fip_test_18.png
# test_results/qr_code_fip_test_45.png
# test_results/qr_code_fip_test_38.png
# test_results/qr_code_fip_test_50.png
# test_results/qr_code_fip_test_22.png
# test_results/qr_code_fip_test_48.png
# test_results/qr_code_fip_test_59.png
# test_results/qr_code_fip_test_77.png
# test_results/qr_code_fip_test_41.png
# test_results/qr_code_fip_test_76.png
# test_results/qr_code_fip_test_4.png
# test_results/qr_code_fip_test_20.png
# test_results/qr_code_fip_test_88.png
# test_results/qr_code_fip_test_43.png
# test_results/qr_code_fip_test_90.png
# test_results/qr_code_fip_test_10.png
# test_results/qr_code_fip_test_68.png
# test_results/qr_code_fip_test_74.png
# test_results/qr_code_fip_test_33.png
# test_results/qr_code_fip_test_97.png
# test_results/qr_code_fip_test_53.png
# test_results/qr_code_fip_test_35.png
# test_results/qr_code_fip_test_92.png
# test_results/qr_code_fip_test_30.png
# test_results/qr_code_fip_test_99.png
# test_results/qr_code_fip_test_26.png
# test_results/qr_code_fip_test_55.png
# test_results/qr_code_fip_test_42.png
# test_results/qr_code_fip_test_49.png
# test_results/qr_code_fip_test_66.png
# test_results/qr_code_fip_test_1.png
# test_results/qr_code_fip_test_32.png
# test_results/qr_code_fip_test_27.png
# test_results/qr_code_fip_test_23.png
# test_results/qr_code_fip_test_19.png
# test_results/qr_code_fip_test_64.png
# test_results/qr_code_fip_test_69.png
# test_results/qr_code_fip_test_17.png
# test_results/qr_code_fip_test_95.png
# test_results/qr_code_fip_test_57.png
# test_results/qr_code_fip_test_46.png
# test_results/qr_code_fip_test_21.png
# test_results/qr_code_fip_test_31.png
