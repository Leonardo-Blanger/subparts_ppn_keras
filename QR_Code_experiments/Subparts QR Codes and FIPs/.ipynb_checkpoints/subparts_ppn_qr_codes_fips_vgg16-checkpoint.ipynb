# qr_codes/images/4747076605.jpg
# qr_codes/images/5036470874.jpg
# qr_codes/images/2685220165.jpg
# qr_codes/fips_all.csv
# qr_codes/fips_train.csv
# qr_codes/qr_codes_train.csv
# qr_codes/qr_codes_all.csv
# qr_codes/fips_test.csv
# qr_codes/qr_codes_test.csv
# qr_codes/qr_codes_valid.csv

# %%
from ppn_keras.networks.subparts_ssd_ppn_vgg16 import SubParts_SSD_PPN_VGG16

network = SubParts_SSD_PPN_VGG16(class_labels = ['qr_code'],
                                 subparts_class_labels = ['fip'],
                                 input_shape = (480,480,3))

network.model.summary()
# Out:
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 480, 480, 3)  0
# __________________________________________________________________________________________________
# preprocess (Lambda)             (None, 480, 480, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 480, 480, 64) 1792        preprocess[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 480, 480, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 240, 240, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 240, 240, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 240, 240, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 120, 120, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 120, 120, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 120, 120, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 120, 120, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 60, 60, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 60, 60, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 60, 60, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 60, 60, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 30, 30, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_1 (MaxPooling (None, 15, 15, 512)  0           block4_pool[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_2 (MaxPooling (None, 8, 8, 512)    0           subparts_max_pool_1[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_3 (MaxPooling (None, 4, 4, 512)    0           subparts_max_pool_2[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 30, 30, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_4 (MaxPooling (None, 2, 2, 512)    0           subparts_max_pool_3[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 30, 30, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# subparts_max_pool_5 (MaxPooling (None, 1, 1, 512)    0           subparts_max_pool_4[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 30, 30, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# subparts_shared_conv (Conv2D)   multiple             262656      block4_pool[0][0]
#                                                                  subparts_max_pool_1[0][0]
#                                                                  subparts_max_pool_2[0][0]
#                                                                  subparts_max_pool_3[0][0]
#                                                                  subparts_max_pool_4[0][0]
#                                                                  subparts_max_pool_5[0][0]
# __________________________________________________________________________________________________
# max_pool_1 (MaxPooling2D)       (None, 15, 15, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# subparts_box_classifier (Conv2D multiple             55308       subparts_shared_conv[0][0]
#                                                                  subparts_shared_conv[1][0]
#                                                                  subparts_shared_conv[2][0]
#                                                                  subparts_shared_conv[3][0]
#                                                                  subparts_shared_conv[4][0]
#                                                                  subparts_shared_conv[5][0]
# __________________________________________________________________________________________________
# max_pool_2 (MaxPooling2D)       (None, 8, 8, 512)    0           max_pool_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 30, 30, 6, 2) 0           subparts_box_classifier[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 15, 15, 6, 2) 0           subparts_box_classifier[1][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 8, 8, 6, 2)   0           subparts_box_classifier[2][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 4, 4, 6, 2)   0           subparts_box_classifier[3][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 2, 2, 6, 2)   0           subparts_box_classifier[4][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 1, 1, 6, 2)   0           subparts_box_classifier[5][0]
# __________________________________________________________________________________________________
# max_pool_3 (MaxPooling2D)       (None, 4, 4, 512)    0           max_pool_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 30, 30, 6, 2) 0           reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 15, 15, 6, 2) 0           reshape_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 8, 8, 6, 2)   0           reshape_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 4, 4, 6, 2)   0           reshape_13[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 2, 2, 6, 2)   0           reshape_17[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 1, 6, 2)   0           reshape_21[0][0]
# __________________________________________________________________________________________________
# max_pool_4 (MaxPooling2D)       (None, 2, 2, 512)    0           max_pool_3[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 30, 30, 12)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 15, 15, 12)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 8, 8, 12)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 4, 4, 12)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 2, 2, 12)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 1, 1, 12)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# subparts_box_regressor (Conv2D) multiple             110616      subparts_shared_conv[0][0]
#                                                                  subparts_shared_conv[1][0]
#                                                                  subparts_shared_conv[2][0]
#                                                                  subparts_shared_conv[3][0]
#                                                                  subparts_shared_conv[4][0]
#                                                                  subparts_shared_conv[5][0]
# __________________________________________________________________________________________________
# max_pool_5 (MaxPooling2D)       (None, 1, 1, 512)    0           max_pool_4[0][0]
# __________________________________________________________________________________________________
# shared_conv (Conv2D)            multiple             262656      block5_conv3[0][0]
#                                                                  max_pool_1[0][0]
#                                                                  max_pool_2[0][0]
#                                                                  max_pool_3[0][0]
#                                                                  max_pool_4[0][0]
#                                                                  max_pool_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 30, 36)   0           reshape_2[0][0]
#                                                                  subparts_box_regressor[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 15, 15, 36)   0           reshape_6[0][0]
#                                                                  subparts_box_regressor[1][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 36)     0           reshape_10[0][0]
#                                                                  subparts_box_regressor[2][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 4, 4, 36)     0           reshape_14[0][0]
#                                                                  subparts_box_regressor[3][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 2, 2, 36)     0           reshape_18[0][0]
#                                                                  subparts_box_regressor[4][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1, 1, 36)     0           reshape_22[0][0]
#                                                                  subparts_box_regressor[5][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 30, 30, 548)  0           shared_conv[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 15, 15, 548)  0           shared_conv[1][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 548)    0           shared_conv[2][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 4, 4, 548)    0           shared_conv[3][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 2, 2, 548)    0           shared_conv[4][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 1, 1, 548)    0           shared_conv[5][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# box_classifier (Conv2D)         multiple             59196       concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  concatenate_12[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 5400, 2)      0           box_classifier[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 1350, 2)      0           box_classifier[1][0]
# __________________________________________________________________________________________________
# reshape_29 (Reshape)            (None, 384, 2)       0           box_classifier[2][0]
# __________________________________________________________________________________________________
# reshape_31 (Reshape)            (None, 96, 2)        0           box_classifier[3][0]
# __________________________________________________________________________________________________
# reshape_33 (Reshape)            (None, 24, 2)        0           box_classifier[4][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 6, 2)         0           box_classifier[5][0]
# __________________________________________________________________________________________________
# box_regressor (Conv2D)          multiple             118392      concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  concatenate_12[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 5400, 2)      0           reshape_2[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1350, 2)      0           reshape_6[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 384, 2)       0           reshape_10[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 96, 2)        0           reshape_14[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 24, 2)        0           reshape_18[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 6, 2)         0           reshape_22[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 5400, 4)      0           subparts_box_regressor[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1350, 4)      0           subparts_box_regressor[1][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 384, 4)       0           subparts_box_regressor[2][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 96, 4)        0           subparts_box_regressor[3][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 24, 4)        0           subparts_box_regressor[4][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 6, 4)         0           subparts_box_regressor[5][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 5400, 2)      0           reshape_25[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1350, 2)      0           reshape_27[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 384, 2)       0           reshape_29[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 96, 2)        0           reshape_31[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 24, 2)        0           reshape_33[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 6, 2)         0           reshape_35[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 5400, 4)      0           box_regressor[0][0]
# __________________________________________________________________________________________________
# reshape_28 (Reshape)            (None, 1350, 4)      0           box_regressor[1][0]
# __________________________________________________________________________________________________
# reshape_30 (Reshape)            (None, 384, 4)       0           box_regressor[2][0]
# __________________________________________________________________________________________________
# reshape_32 (Reshape)            (None, 96, 4)        0           box_regressor[3][0]
# __________________________________________________________________________________________________
# reshape_34 (Reshape)            (None, 24, 4)        0           box_regressor[4][0]
# __________________________________________________________________________________________________
# reshape_36 (Reshape)            (None, 6, 4)         0           box_regressor[5][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7260, 2)      0           reshape_3[0][0]
#                                                                  reshape_7[0][0]
#                                                                  reshape_11[0][0]
#                                                                  reshape_15[0][0]
#                                                                  reshape_19[0][0]
#                                                                  reshape_23[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7260, 4)      0           reshape_4[0][0]
#                                                                  reshape_8[0][0]
#                                                                  reshape_12[0][0]
#                                                                  reshape_16[0][0]
#                                                                  reshape_20[0][0]
#                                                                  reshape_24[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 7260, 2)      0           activation_7[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_9[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 7260, 4)      0           reshape_26[0][0]
#                                                                  reshape_28[0][0]
#                                                                  reshape_30[0][0]
#                                                                  reshape_32[0][0]
#                                                                  reshape_34[0][0]
#                                                                  reshape_36[0][0]
# __________________________________________________________________________________________________
# subparts_output (Concatenate)   (None, 7260, 6)      0           concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# main_output (Concatenate)       (None, 7260, 6)      0           concatenate_15[0][0]
#                                                                  concatenate_16[0][0]
# ==================================================================================================
# Total params: 15,583,512
# Trainable params: 15,583,512
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from imgaug import augmenters as iaa
import numpy as np

# Sometimes(0.5, ...) applies the given augmenter in 50% of all cases,
# e.g. Sometimes(0.5, GaussianBlur(0.3)) would blur roughly every second
# image.
sometimes = lambda aug: iaa.Sometimes(0.5, aug)

# Define our sequence of augmentation steps that will be applied to every image.
augmentation_seq = iaa.Sequential(
    [
        #
        # Apply the following augmenters to most images.
        #
        iaa.Fliplr(0.5), # horizontally flip 50% of all images
        iaa.Flipud(0.2), # vertically flip 20% of all images

        # crop some of the images by 0-10% of their height/width
        sometimes(iaa.Crop(percent=(0, 0.1))),

        # Apply affine transformations to some of the images
        # - scale to 80-120% of image height/width (each axis independently)
        # - translate by -20 to +20 relative to height/width (per axis)
        # - rotate by -45 to +45 degrees
        # - shear by -16 to +16 degrees
        # - order: use nearest neighbour or bilinear interpolation (fast)
        # - mode: use any available mode to fill newly created pixels
        #         see API or scikit-image for which modes are available
        # - cval: if the mode is constant, then use a random brightness
        #         for the newly created pixels (e.g. sometimes black,
        #         sometimes white)
        sometimes(iaa.Affine(
            scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            rotate=(-45, 45),
            shear=(-16, 16),
            order=[0, 1],
            cval=(0, 255),
            mode=ia.ALL
        )),

        #
        # Execute 0 to 5 of the following (less important) augmenters per
        # image. Don't execute all of them, as that would often be way too
        # strong.
        #
        iaa.SomeOf((0, 5),
            [
                # Convert some images into their superpixel representation,
                # sample between 20 and 200 superpixels per image, but do
                # not replace all superpixels with their average, only
                # some of them (p_replace).
                sometimes(
                    iaa.Superpixels(
                        p_replace=(0, 1.0),
                        n_segments=(20, 200)
                    )
                ),

                # Blur each image with varying strength using
                # gaussian blur (sigma between 0 and 3.0),
                # average/uniform blur (kernel size between 2x2 and 7x7)
                # median blur (kernel size between 3x3 and 11x11).
                iaa.OneOf([
                    iaa.GaussianBlur((0, 3.0)),
                    iaa.AverageBlur(k=(2, 7)),
                    iaa.MedianBlur(k=(3, 11)),
                ]),

                # Sharpen each image, overlay the result with the original
                # image using an alpha between 0 (no sharpening) and 1
                # (full sharpening effect).
                iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)),

                # Same as sharpen, but for an embossing effect.
                iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)),

                # Search in some images either for all edges or for
                # directed edges. These edges are then marked in a black
                # and white image and overlayed with the original image
                # using an alpha of 0 to 0.7.
                sometimes(iaa.OneOf([
                    iaa.EdgeDetect(alpha=(0, 0.7)),
                    iaa.DirectedEdgeDetect(
                        alpha=(0, 0.7), direction=(0.0, 1.0)
                    ),
                ])),

                # Add gaussian noise to some images.
                # In 50% of these cases, the noise is randomly sampled per
                # channel and pixel.
                # In the other 50% of all cases it is sampled once per
                # pixel (i.e. brightness change).
                iaa.AdditiveGaussianNoise(
                    loc=0, scale=(0.0, 0.05*255), per_channel=0.5
                ),

                # Either drop randomly 1 to 10% of all pixels (i.e. set
                # them to black) or drop them on an image with 2-5% percent
                # of the original size, leading to large dropped
                # rectangles.
                iaa.OneOf([
                    iaa.Dropout((0.01, 0.1), per_channel=0.5),
                    iaa.CoarseDropout(
                        (0.03, 0.15), size_percent=(0.02, 0.05),
                        per_channel=0.2
                    ),
                ]),

                # Invert each image's chanell with 5% probability.
                # This sets each pixel value v to 255-v.
                iaa.Invert(0.05, per_channel=True), # invert color channels

                # Add a value of -10 to 10 to each pixel.
                iaa.Add((-10, 10), per_channel=0.5),

                # Change brightness of images (50-150% of original value).
                iaa.Multiply((0.5, 1.5), per_channel=0.5),

                # Improve or worsen the contrast of images.
                iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5),

                # Convert each image to grayscale and then overlay the
                # result with the original with random alpha. I.e. remove
                # colors with varying strengths.
                iaa.Grayscale(alpha=(0.0, 1.0)),

                # In some images move pixels locally around (with random
                # strengths).
                sometimes(
                    iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)
                ),

                # In some images distort local areas with varying strength.
                sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05)))
            ],
            # do all of the above augmentations in random order
            random_order=True
        )
    ],
    # do all of the above augmentations in random order
    random_order=True
)

# %%
import pandas as pd

train_qr_codes = pd.read_csv('qr_codes_train.csv', dtype={'image_id': str, 'object_id': str})
valid_qr_codes = pd.read_csv('qr_codes_valid.csv', dtype={'image_id': str, 'object_id': str})

train_fips = pd.read_csv('fips_train.csv', dtype={'image_id': str, 'object_id': str})
valid_fips = pd.read_csv('fips_valid.csv', dtype={'image_id': str, 'object_id': str})

from ppn_keras.subparts_batch_generator import SubPartsBatchGenerator

batch_generator_train = SubPartsBatchGenerator(network)
batch_generator_valid = SubPartsBatchGenerator(network)

batch_generator_train.add_data(dataset = train_qr_codes, subparts_dataset = train_fips, images_dir='images')
batch_generator_valid.add_data(dataset = valid_qr_codes, subparts_dataset = valid_fips, images_dir='images')

batch_size = 8

valid_generator, valid_size = batch_generator_valid.get_generator(batch_size = 1, shuffle = False, augmentation = False, encode_output = False)
valid_X, valid_y_subparts, valid_y_obj = [], [], []

for _ in range(valid_size):
  batch_X, batch_y = next(valid_generator)
  valid_X.append(batch_X[0])
  valid_y_subparts.append(batch_y[0][0])
  valid_y_obj.append(batch_y[1][0])
  
valid_X = np.array(valid_X)

train_generator, train_size = batch_generator_train.get_generator(batch_size=batch_size, shuffle=True, augmentation=augmentation_seq, encode_output=True)
valid_generator, valid_size = batch_generator_valid.get_generator(batch_size = batch_size, shuffle = False, augmentation = False, encode_output = True)

print('%d training images' % train_size)
print('%d validation images' % valid_size)

train_generator_vis, _ = batch_generator_train.get_generator(batch_size=1, shuffle=True, augmentation=augmentation_seq, encode_output=False)

batch_X, batch_y = next(train_generator)
print(batch_X.shape)
print(batch_y[0].shape, batch_y[1].shape)

fig = plt.figure(figsize=(20,20))

for i in range(6):
  batch_X, batch_y = next(train_generator_vis)
  img = batch_X[0]
  subpart_boxes, obj_boxes = batch_y[0][0], batch_y[1][0]
  
  img = obj_boxes.draw_on_image(img, thickness=6)
  img = subpart_boxes.draw_on_image(img, thickness=4, color=[255,0,0])
  
  ax = fig.add_subplot(3, 2, i+1)
  ax.imshow(img)
  
print(batch_y)
# Out:
# Preprocessing Dataset: 100%|██████████| 962/962 [00:34<00:00, 27.67it/s]
# Preprocessing Dataset: 100%|██████████| 143/143 [00:05<00:00, 24.73it/s]
# 567 training images
# 100 validation images
# (8, 480, 480, 3)
# (8, 7260, 6) (8, 7260, 6)
# [[BoundingBoxesOnImage([BoundingBox(x1=176.0000, y1=114.4913, x2=211.3359, y2=149.3581, label=fip), BoundingBox(x1=286.4556, y1=127.2995, x2=321.0502, y2=161.4548, label=fip), BoundingBox(x1=152.5251, y1=231.9000, x2=191.0734, y2=271.3920, label=fip)], shape=(480, 480, 3))], [BoundingBoxesOnImage([BoundingBox(x1=152.5251, y1=114.4913, x2=321.0502, y2=286.6907, label=qr_code)], shape=(480, 480, 3))]]

# %%
import keras
from ppn_keras import metrics

network.model.compile(
  optimizer = keras.optimizers.Adam(1e-4, decay=1e-4),
  loss = {'subparts_output': metrics.get_ppn_loss(), 'main_output': metrics.get_ppn_loss()},
  loss_weights = {'subparts_output': 1.0, 'main_output': 1.0}
)

# %%
from keras.callbacks import Callback, ModelCheckpoint
from ppn_keras.encode_decode_output import output_decoder
from ppn_keras.encode_decode_subparts_output import subparts_output_decoder

class PrintMetricsOnEnd(Callback):
  def __init__(self):
    super(PrintMetricsOnEnd, self).__init__()
    
  def on_epoch_end(self, epoch, logs=None):
    logs = logs or {}
    for k in self.params['metrics']:
      if k in logs:
        print('%s: %.10f' % (k, logs[k]))
    print()
    
class EvaluateValidMeanAP(Callback):
  def __init__(self):
    super(EvaluateValidMeanAP, self).__init__()
    self.best_mAP = 0
    
  def on_epoch_end(self, epoch, logs=None):
    y_pred = network.model.predict(valid_X, batch_size = batch_size, verbose = 0)
    y_pred = [
        subparts_output_decoder(y_pred[0], network, nms_threshold = 0.3),
        output_decoder(y_pred[1], network, nms_threshold = 0.3)
    ]
    
    APs = [
        metrics.AP(valid_y_subparts, y_pred[0]),
        metrics.AP(valid_y_obj, y_pred[1])
    ]
    
    print('Validation APs:', APs)
    print()
    
    if APs[1] > self.best_mAP:
      self.best_mAP = APs[1]
      network.model.save('subparts_ppn_vgg16_qr_codes_fips.%03d-%.6f_mAP.hdf5' % (epoch, APs[1]))

# !rm subparts_ppn_vgg16_qr_codes_fips.*

network.model.fit_generator(train_generator,
                            steps_per_epoch = 50,
                            epochs = 100,
                            validation_data = valid_generator,
                            validation_steps = int(np.floor(valid_size / batch_size)),
                            verbose = 1,
                            max_queue_size = 200,
                            callbacks = [
                                PrintMetricsOnEnd(),
                                EvaluateValidMeanAP()
                            ])
# Out:
# rm: cannot remove 'subparts_ppn_vgg16_qr_codes_fips.*': No such file or directory
# Epoch 1/100
# 50/50 [==============================] - 254s 5s/step - loss: 1.2086 - subparts_output_loss: 0.8216 - main_output_loss: 0.3870 - val_loss: 0.0216 - val_subparts_output_loss: 0.0134 - val_main_output_loss: 0.0083
# loss: 1.2085538570
# subparts_output_loss: 0.8215718299
# main_output_loss: 0.3869819995
# val_loss: 0.0216419643
# val_subparts_output_loss: 0.0133874495
# val_main_output_loss: 0.0082545150
#
# Validation APs: [0.0, 7.439369141496801e-05]
#
# Epoch 2/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.0159 - subparts_output_loss: 0.0100 - main_output_loss: 0.0059 - val_loss: 0.0113 - val_subparts_output_loss: 0.0069 - val_main_output_loss: 0.0044
# loss: 0.0159187705
# subparts_output_loss: 0.0100334069
# main_output_loss: 0.0058853635
# val_loss: 0.0112586013
# val_subparts_output_loss: 0.0068808089
# val_main_output_loss: 0.0043777923
#
# Validation APs: [0.0, 0.0]
#
# Epoch 3/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.
- val_subparts_output_loss: 0.0018 - val_main_output_loss: 6.3123e-04
# loss: 0.0035747345
# subparts_output_loss: 0.0023197080
# main_output_loss: 0.0012550264
# val_loss: 0.0024495375
# val_subparts_output_loss: 0.0018183046
# val_main_output_loss: 0.0006312329
#
# Validation APs: [0.0, 0.6293943855298569]
#
# Epoch 59/100
# 50/50 [==============================] - 100s 2s/step - loss: 0.0032 - subparts_output_loss: 0.0021 - main_output_loss: 0.0011 - val_loss: 0.0024 - val_subparts_output_loss: 0.0018 - val_main_output_loss: 6.3420e-04
# loss: 0.0031560276
# subparts_output_loss: 0.0020642956
# main_output_loss: 0.0010917320
# val_loss: 0.0024262529
# val_subparts_output_loss: 0.0017920534
# val_main_output_loss: 0.0006341995
#
# Validation APs: [0.0, 0.5675288311918912]
#
# Epoch 60/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0036 - subparts_output_loss: 0.0021 - main_output_loss: 0.0014 - val_loss: 0.0027 - val_subparts_output_loss: 0.0018 - val_main_output_loss: 8.4153e-04
# loss: 0.0035634374
# subparts_output_loss: 0.0021319450
# main_output_loss: 0.0014314924
# val_loss: 0.0026871347
# val_subparts_output_loss: 0.0018456009
# val_main_output_loss: 0.0008415338
#
# Validation APs: [0.0, 0.568426726324354]
#
# Epoch 61/100
# 50/50 [==============================] - 107s 2s/step - loss: 0.0037 - subparts_output_loss: 0.0023 - main_output_loss: 0.0014 - val_loss: 0.0025 - val_subparts_output_loss: 0.0018 - val_main_output_loss: 6.3048e-04
# loss: 0.0037118691
# subparts_output_loss: 0.0022910278
# main_output_loss: 0.0014208413
# val_loss: 0.0024582966
# val_subparts_output_loss: 0.0018278186
# val_main_output_loss: 0.0006304779
#
# Validation APs: [0, 0.6318549687890218]
#
# Epoch 62/100
# 50/50 [==============================] - 110s 2s/step - loss: 0.0038 - subparts_output_loss: 0.0024 - main_output_loss: 0.0014 - val_loss: 0.0025 - val_subparts_output_loss: 0.0018 - val_main_output_loss: 6.5633e-04
# loss: 0.0037749357
# subparts_output_loss: 0.0024067450
# main_output_loss: 0.0013681908
# val_loss: 0.0024554107
# val_subparts_output_loss: 0.0017990766
# val_main_output_loss: 0.0006563341
#
# Validation APs: [0.0, 0.4941215912002435]
#
# Epoch 63/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.0033 - subparts_output_loss: 0.0022 - main_output_loss: 0.0012 - val_loss: 0.0030 - val_subparts_output_loss: 0.0019 - val_main_output_loss: 0.0010
# loss: 0.0033251024
# subparts_output_loss: 0.0021557797
# main_output_loss: 0.0011693228
# val_loss: 0.0029732509
# val_subparts_output_loss: 0.0019465530
# val_main_output_loss: 0.0010266979
#
# Validation APs: [0.0, 0.4438480736837245]
#
# Epoch 64/100
# 50/50 [==============================] - 94s 2s/step - loss: 0.0038 - subparts_output_loss: 0.0023 - main_output_loss: 0.0014 - val_loss: 0.0023 - val_subparts_output_loss: 0.0017 - val_main_output_loss: 6.0794e-04
# loss: 0.0037704040
# subparts_output_loss: 0.0023221816
# main_output_loss: 0.0014482223
# val_loss: 0.0023491662
# val_subparts_output_loss: 0.0017412269
# val_main_output_loss: 0.0006079392
#
# Validation APs: [0.0, 0.6019835372101492]
#
# Epoch 65/100
# 50/50 [==============================] - 96s 2s/step - loss: 0.0034 - subparts_output_loss: 0.0022 - main_output_loss: 0.0012 - val_loss: 0.0024 - val_subparts_output_loss: 0.0017 - val_main_output_loss:
- val_subparts_output_loss: 0.0015 - val_main_output_loss: 5.1539e-04
# loss: 0.0027614275
# subparts_output_loss: 0.0018431214
# main_output_loss: 0.0009183061
# val_loss: 0.0019922751
# val_subparts_output_loss: 0.0014768811
# val_main_output_loss: 0.0005153939
#
# Validation APs: [0.005597735169218891, 0.6126235105113316]
#
# Epoch 87/100
# 50/50 [==============================] - 107s 2s/step - loss: 0.0029 - subparts_output_loss: 0.0019 - main_output_loss: 9.9081e-04 - val_loss: 0.0020 - val_subparts_output_loss: 0.0015 - val_main_output_loss: 5.3161e-04
# loss: 0.0028905250
# subparts_output_loss: 0.0018997193
# main_output_loss: 0.0009908057
# val_loss: 0.0020266459
# val_subparts_output_loss: 0.0014950354
# val_main_output_loss: 0.0005316106
#
# Validation APs: [0.003918054943886771, 0.7077195067281171]
#
# Epoch 88/100
# 50/50 [==============================] - 99s 2s/step - loss: 0.0030 - subparts_output_loss: 0.0019 - main_output_loss: 0.0011 - val_loss: 0.0020 - val_subparts_output_loss: 0.0015 - val_main_output_loss: 5.1057e-04
# loss: 0.0029688696
# subparts_output_loss: 0.0018559129
# main_output_loss: 0.0011129567
# val_loss: 0.0019791290
# val_subparts_output_loss: 0.0014685627
# val_main_output_loss: 0.0005105663
#
# Validation APs: [0.013098148794970312, 0.6591946855609334]
#
# Epoch 89/100
# 50/50 [==============================] - 98s 2s/step - loss: 0.0031 - subparts_output_loss: 0.0020 - main_output_loss: 0.0011 - val_loss: 0.0023 - val_subparts_output_loss: 0.0016 - val_main_output_loss: 7.1790e-04
# loss: 0.0031243118
# subparts_output_loss: 0.0020194561
# main_output_loss: 0.0011048557
# val_loss: 0.0022909925
# val_subparts_output_loss: 0.0015730930
# val_main_output_loss: 0.0007178996
#
# Validation APs: [0.006782577198225119, 0.6727108353768516]
#
# Epoch 90/100
# 50/50 [==============================] - 99s 2s/step - loss: 0.0027 - subparts_output_loss: 0.0017 - main_output_loss: 9.9198e-04 - val_loss: 0.0019 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 4.9966e-04
# loss: 0.0027223660
# subparts_output_loss: 0.0017303901
# main_output_loss: 0.0009919759
# val_loss: 0.0019184678
# val_subparts_output_loss: 0.0014188126
# val_main_output_loss: 0.0004996552
#
# Validation APs: [0.012620521692713174, 0.6867910391909928]
#
# Epoch 91/100
# 50/50 [==============================] - 128s 3s/step - loss: 0.0031 - subparts_output_loss: 0.0019 - main_output_loss: 0.0012 - val_loss: 0.0023 - val_subparts_output_loss: 0.0015 - val_main_output_loss: 8.3086e-04
# loss: 0.0030934835
# subparts_output_loss: 0.0019376485
# main_output_loss: 0.0011558350
# val_loss: 0.0022902719
# val_subparts_output_loss: 0.0014594163
# val_main_output_loss: 0.0008308556
#
# Validation APs: [0.0070904645476772615, 0.5967442125631067]
#
# Epoch 92/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0028 - subparts_output_loss: 0.0018 - main_output_loss: 0.0010 - val_loss: 0.0018 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 4.6044e-04
# loss: 0.0028195642
# subparts_output_loss: 0.0018140547
# main_output_loss: 0.0010055095
# val_loss: 0.0018393305
# val_subparts_output_loss: 0.0013788902
# val_main_output_loss: 0.0004604403
#
# Validation APs: [0.016617628776262897, 0.6988870788677348]
#
# Epoch 93/100
# 50/50 [==============================] - 105s 2s/step - loss: 0.0028 - subparts_output_loss: 0.0018 - main_output_loss: 0.0010 - val_loss: 0.0019 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 5.0587e-04
# loss: 0.0028190498
# subparts_output_loss: 0.0017724009
# main_output_loss: 0.0010466489
# val_loss: 0.0019001690
# val_subparts_output_loss: 0.0013942982
# val_main_output_loss: 0.0005058707
#
# Validation APs: [0.015610306563851798, 0.6954327633590365]
#
# Epoch 94/100
# 50/50 [==============================] - 130s 3s/step - loss: 0.0032 - subparts_output_loss: 0.0019 - main_output_loss: 0.0013 - val_loss: 0.0019 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 5.0060e-04
# loss: 0.0032270994
# subparts_output_loss: 0.0019390802
# main_output_loss: 0.0012880192
# val_loss: 0.0018733776
# val_subparts_output_loss: 0.0013727750
# val_main_output_loss: 0.0005006026
#
# Validation APs: [0.009532982638117114, 0.702965572061441]
#
# Epoch 95/100
# 50/50 [==============================] - 129s 3s/step - loss: 0.0027 - subparts_output_loss: 0.0017 - main_output_loss: 9.7220e-04 - val_loss: 0.0020 - val_subparts_output_loss: 0.0015 - val_main_output_loss: 5.3433e-04
# loss: 0.0026650096
# subparts_output_loss: 0.0016928115
# main_output_loss: 0.0009721981
# val_loss: 0.0019849026
# val_subparts_output_loss: 0.0014505773
# val_main_output_loss: 0.0005343252
#
# Validation APs: [0.015762576868933835, 0.67876794201236]
#
# Epoch 96/100
# 50/50 [==============================] - 125s 3s/step - loss: 0.0031 - subparts_output_loss: 0.0019 - main_output_loss: 0.0011 - val_loss: 0.0019 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 5.0324e-04
# loss: 0.0030694851
# subparts_output_loss: 0.0019228053
# main_output_loss: 0.0011466798
# val_loss: 0.0018723410
# val_subparts_output_loss: 0.0013691040
# val_main_output_loss: 0.0005032371
#
# Validation APs: [0.017307094608594756, 0.6242019554570557]
#
# Epoch 97/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.0028 - subparts_output_loss: 0.0018 - main_output_loss: 9.5206e-04 - val_loss: 0.0017 - val_subparts_output_loss: 0.0013 - val_main_output_loss: 4.0756e-04
# loss: 0.0027769851
# subparts_output_loss: 0.0018249271
# main_output_loss: 0.0009520580
# val_loss: 0.0017319067
# val_subparts_output_loss: 0.0013243481
# val_main_output_loss: 0.0004075586
#
# Validation APs: [0.017686157192012292, 0.6576603751104283]
#
# Epoch 98/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.0027 - subparts_output_loss: 0.0017 - main_output_loss: 9.2825e-04 - val_loss: 0.0019 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 4.8225e-04
# loss: 0.0026504677
# subparts_output_loss: 0.0017222160
# main_output_loss: 0.0009282518
# val_loss: 0.0018578812
# val_subparts_output_loss: 0.0013756291
# val_main_output_loss: 0.0004822521
#
# Validation APs: [0.017235849304624445, 0.5988346150624884]
#
# Epoch 99/100
# 50/50 [==============================] - 93s 2s/step - loss: 0.0029 - subparts_output_loss: 0.0018 - main_output_loss: 0.0012 - val_loss: 0.0018 - val_subparts_output_loss: 0.0013 - val_main_output_loss: 4.6901e-04
# loss: 0.0029376347
# subparts_output_loss: 0.0017807345
# main_output_loss: 0.0011569001
# val_loss: 0.0017803904
# val_subparts_output_loss: 0.0013113772
# val_main_output_loss: 0.0004690132
#
# Validation APs: [0.019058502771007988, 0.7115966486286303]
#
# Epoch 100/100
# 50/50 [==============================] - 113s 2s/step - loss: 0.0029 - subparts_output_loss: 0.0018 - main_output_loss: 0.0011 - val_loss: 0.0018 - val_subparts_output_loss: 0.0014 - val_main_output_loss: 4.7716e-04
# loss: 0.0029201497
# subparts_output_loss: 0.0018226086
# main_output_loss: 0.0010975411
# val_loss: 0.0018277556
# val_subparts_output_loss: 0.0013505994
# val_main_output_loss: 0.0004771562
#
# Validation APs: [0.012342941387030038, 0.5920760550119055]

# %%
# !ls -l
# Out:
# total 4571180
# -rw-r--r-- 1 root root     19652 Jan 24 21:08 fips_test.csv
# -rw-r--r-- 1 root root    124866 Jan 24 21:08 fips_train.csv
# -rw-r--r-- 1 root root     18679 Jan 24 21:08 fips_valid.csv
# drwxr-xr-x 2 root root     36864 Jan 24 21:08 images
# drwx------ 8 root root      4096 Jan 24 21:07 ppn_keras
# -rw-r--r-- 1 root root      7819 Jan 24 21:08 qr_codes_test.csv
# -rw-r--r-- 1 root root     47591 Jan 24 21:08 qr_codes_train.csv
# -rw-r--r-- 1 root root      7135 Jan 24 21:08 qr_codes_valid.csv
# drwxr-xr-x 1 root root      4096 Jan  8 17:15 sample_data
# -rw-r--r-- 1 root root 187223136 Jan 24 21:13 subparts_ppn_vgg16_qr_codes_fips.000-0.000074_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:29 subparts_ppn_vgg16_qr_codes_fips.008-0.001166_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:43 subparts_ppn_vgg16_qr_codes_fips.015-0.019532_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:44 subparts_ppn_vgg16_qr_codes_fips.016-0.074580_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:46 subparts_ppn_vgg16_qr_codes_fips.017-0.121454_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:48 subparts_ppn_vgg16_qr_codes_fips.018-0.179741_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:50 subparts_ppn_vgg16_qr_codes_fips.019-0.192659_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:52 subparts_ppn_vgg16_qr_codes_fips.020-0.241296_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:54 subparts_ppn_vgg16_qr_codes_fips.021-0.272644_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 21:58 subparts_ppn_vgg16_qr_codes_fips.023-0.296340_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:04 subparts_ppn_vgg16_qr_codes_fips.026-0.366263_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:10 subparts_ppn_vgg16_qr_codes_fips.029-0.370029_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:19 subparts_ppn_vgg16_qr_codes_fips.034-0.439367_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:26 subparts_ppn_vgg16_qr_codes_fips.037-0.539767_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:30 subparts_ppn_vgg16_qr_codes_fips.039-0.546379_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:35 subparts_ppn_vgg16_qr_codes_fips.042-0.612310_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:42 subparts_ppn_vgg16_qr_codes_fips.046-0.636021_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 22:50 subparts_ppn_vgg16_qr_codes_fips.050-0.644409_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 23:21 subparts_ppn_vgg16_qr_codes_fips.066-0.661171_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 23:23 subparts_ppn_vgg16_qr_codes_fips.067-0.684743_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 23:25 subparts_ppn_vgg16_qr_codes_fips.068-0.701741_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 23:30 subparts_ppn_vgg16_qr_codes_fips.071-0.704538_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 23:42 subparts_ppn_vgg16_qr_codes_fips.077-0.704932_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 23:44 subparts_ppn_vgg16_qr_codes_fips.078-0.707902_mAP.hdf5
# -rw-r--r-- 1 root root 187223136 Jan 24 23:50 subparts_ppn_vgg16_qr_codes_fips.081-0.717012_mAP.hdf5

# %%
from ppn_keras.encode_decode_output import output_decoder
from ppn_keras.encode_decode_subparts_output import subparts_output_decoder
from google.colab import files

from glob import glob
model_path = sorted(glob('subparts_ppn_vgg16_qr_codes_fips.*'))[-1]
print(model_path)

import keras
from keras.utils.generic_utils import CustomObjectScope

with CustomObjectScope({'vgg16': keras.applications.vgg16,
                        'relu6': keras.layers.ReLU(6.),
                        'ppn_loss': metrics.get_ppn_loss()}):
    model = keras.models.load_model(model_path)

#model = network.model

y_pred = model.predict(valid_X, batch_size = batch_size)
y_pred = [
    subparts_output_decoder(y_pred[0], network, nms_threshold = 0.3),
    output_decoder(y_pred[1], network, nms_threshold = 0.3)
]

APs = [
    metrics.AP(valid_y_subparts, y_pred[0]),
    metrics.AP(valid_y_obj, y_pred[1])
]

print('Validation APs:', APs)

for i in range(valid_size):
  img, subpart_boxes, obj_boxes = valid_X[i], y_pred[0][i], y_pred[1][i]

  img = obj_boxes.draw_on_image(img, thickness=6)
  img = subpart_boxes.draw_on_image(img, thickness=4, color=[255,0,0])
  
  cv.imwrite('qr_code_fip_valid_%d.png'%i, img[..., [2,1,0]])
  
# !rm qr_code_fip_valid_subparts_vgg16.tar.gz valid_results/*
# !mkdir valid_results
# !mv qr_code_fip_valid* valid_results
# !tar -cvf qr_code_fip_valid_subparts_vgg16.tar.gz valid_results
# Out:
# subparts_ppn_vgg16_qr_codes_fips.081-0.717012_mAP.hdf5
# Validation APs: [0.008865648949066177, 0.7170122432351074]
# rm: cannot remove 'qr_code_fip_valid_subparts_vgg16.tar.gz': No such file or directory
# rm: cannot remove 'valid_results/*': No such file or directory
# valid_results/
# valid_results/qr_code_fip_valid_29.png
# valid_results/qr_code_fip_valid_96.png
# valid_results/qr_code_fip_valid_14.png
# valid_results/qr_code_fip_valid_99.png
# valid_results/qr_code_fip_valid_36.png
# valid_results/qr_code_fip_valid_76.png
# valid_results/qr_code_fip_valid_3.png
# valid_results/qr_code_fip_valid_37.png
# valid_results/qr_code_fip_valid_9.png
# valid_results/qr_code_fip_valid_86.png
# valid_results/qr_code_fip_valid_88.png
# valid_results/qr_code_fip_valid_55.png
# valid_results/qr_code_fip_valid_10.png
# valid_results/qr_code_fip_valid_40.png
# valid_results/qr_code_fip_valid_34.png
# valid_results/qr_code_fip_valid_39.png
# valid_results/qr_code_fip_valid_64.png
# valid_results/qr_code_fip_valid_63.png
# valid_results/qr_code_fip_valid_80.png
# valid_results/qr_code_fip_valid_53.png
# valid_results/qr_code_fip_valid_89.png
# valid_results/qr_code_fip_valid_25.png
# valid_results/qr_code_fip_valid_57.png
# valid_results/qr_code_fip_valid_91.png
# valid_results/qr_code_fip_valid_23.png
# valid_results/qr_code_fip_valid_49.png
# valid_results/qr_code_fip_valid_54.png
# valid_results/qr_code_fip_valid_32.png
# valid_results/qr_code_fip_valid_98.png
# valid_results/qr_code_fip_valid_69.png
# valid_results/qr_code_fip_valid_84.png
# valid_results/qr_code_fip_valid_83.png
# valid_results/qr_code_fip_valid_94.png
# valid_results/qr_code_fip_valid_24.png
# valid_results/qr_code_fip_valid_48.png
# valid_results/qr_code_fip_valid_26.png
# valid_results/qr_code_fip_valid_52.png
# valid_results/qr_code_fip_valid_45.png
# valid_results/qr_code_fip_valid_15.png
# valid_results/qr_code_fip_valid_11.png
# valid_results/qr_code_fip_valid_58.png
# valid_results/qr_code_fip_valid_77.png
# valid_results/qr_code_fip_valid_35.png
# valid_results/qr_code_fip_valid_13.png
# valid_results/qr_code_fip_valid_90.png
# valid_results/qr_code_fip_valid_27.png
# valid_results/qr_code_fip_valid_2.png
# valid_results/qr_code_fip_valid_85.png
# valid_results/qr_code_fip_valid_19.png
# valid_results/qr_code_fip_valid_97.png
# valid_results/qr_code_fip_valid_75.png
# valid_results/qr_code_fip_valid_31.png
# valid_results/qr_code_fip_valid_47.png
# valid_results/qr_code_fip_valid_60.png
# valid_results/qr_code_fip_valid_73.png
# valid_results/qr_code_fip_valid_72.png
# valid_results/qr_code_fip_valid_22.png
# valid_results/qr_code_fip_valid_70.png
# valid_results/qr_code_fip_valid_71.png
# valid_results/qr_code_fip_valid_43.png
# valid_results/qr_code_fip_valid_4.png
# valid_results/qr_code_fip_valid_78.png
# valid_results/qr_code_fip_valid_20.png
# valid_results/qr_code_fip_valid_21.png
# valid_results/qr_code_fip_valid_56.png
# valid_results/qr_code_fip_valid_12.png
# valid_results/qr_code_fip_valid_0.png
# valid_results/qr_code_fip_valid_8.png
# valid_results/qr_code_fip_valid_38.png
# valid_results/qr_code_fip_valid_66.png
# valid_results/qr_code_fip_valid_41.png
# valid_results/qr_code_fip_valid_17.png
# valid_results/qr_code_fip_valid_42.png
# valid_results/qr_code_fip_valid_67.png
# valid_results/qr_code_fip_valid_61.png
# valid_results/qr_code_fip_valid_92.png
# valid_results/qr_code_fip_valid_46.png
# valid_results/qr_code_fip_valid_30.png
# valid_results/qr_code_fip_valid_51.png
# valid_results/qr_code_fip_valid_82.png
# valid_results/qr_code_fip_valid_59.png
# valid_results/qr_code_fip_valid_50.png
# valid_results/qr_code_fip_valid_1.png
# valid_results/qr_code_fip_valid_95.png
# valid_results/qr_code_fip_valid_74.png
# valid_results/qr_code_fip_valid_44.png
# valid_results/qr_code_fip_valid_5.png
# valid_results/qr_code_fip_valid_87.png
# valid_results/qr_code_fip_valid_81.png
# valid_results/qr_code_fip_valid_7.png
# valid_results/qr_code_fip_valid_93.png
# valid_results/qr_code_fip_valid_79.png
# valid_results/qr_code_fip_valid_65.png
# valid_results/qr_code_fip_valid_18.png
# valid_results/qr_code_fip_valid_28.png
# valid_results/qr_code_fip_valid_62.png
# valid_results/qr_code_fip_valid_6.png
# valid_results/qr_code_fip_valid_16.png
# valid_results/qr_code_fip_valid_68.png
# valid_results/qr_code_fip_valid_33.png

# %%
test_qr_codes = pd.read_csv('qr_codes_test.csv', dtype={'image_id': str, 'object_id': str})
test_fips = pd.read_csv('fips_test.csv', dtype={'image_id': str, 'object_id': str})

batch_generator_test = SubPartsBatchGenerator(network)
batch_generator_test.add_data(dataset = test_qr_codes, subparts_dataset = test_fips, images_dir='images')

test_generator, test_size = batch_generator_test.get_generator(batch_size = 1, shuffle = False, augmentation = False, encode_output = False)
test_X, test_y_subparts, test_y_obj = [], [], []

for _ in range(test_size):
  batch_X, batch_y = next(test_generator)
  test_X.append(batch_X[0])
  test_y_subparts.append(batch_y[0][0])
  test_y_obj.append(batch_y[1][0])
  
test_X = np.array(test_X)


from ppn_keras.encode_decode_output import output_decoder
from ppn_keras.encode_decode_subparts_output import subparts_output_decoder
from google.colab import files

from glob import glob
model_path = sorted(glob('subparts_ppn_vgg16_qr_codes_fips.*'))[-1]
print(model_path)

import keras
from keras.utils.generic_utils import CustomObjectScope

with CustomObjectScope({'vgg16': keras.applications.vgg16,
                        'relu6': keras.layers.ReLU(6.),
                        'ppn_loss': metrics.get_ppn_loss()}):
    model = keras.models.load_model(model_path)

#model = network.model

y_pred = model.predict(test_X, batch_size = batch_size)
y_pred = [
    subparts_output_decoder(y_pred[0], network, nms_threshold = 0.3),
    output_decoder(y_pred[1], network, nms_threshold = 0.3)
]

APs = [
    metrics.AP(test_y_subparts, y_pred[0]),
    metrics.AP(test_y_obj, y_pred[1])
]

print('Test APs:', APs)

for i in range(test_size):
  img, subpart_boxes, obj_boxes = valid_X[i], y_pred[0][i], y_pred[1][i]

  img = obj_boxes.draw_on_image(img, thickness=6)
  img = subpart_boxes.draw_on_image(img, thickness=4, color=[255,0,0])
  
  cv.imwrite('qr_code_fip_test_%d.png'%i, img[..., [2,1,0]])
  
# !rm qr_code_test_subparts_vgg16.tar.gz test_results/*
# !mkdir test_results
# !mv qr_code_fip_test* test_results
# !tar -cvf qr_code_test_subparts_vgg16.tar.gz test_results
# Out:
# Preprocessing Dataset: 100%|██████████| 158/158 [00:05<00:00, 28.67it/s]
# subparts_ppn_vgg16_qr_codes_fips.081-0.717012_mAP.hdf5
# Test APs: [0.005224660397074189, 0.6754323886665385]
# rm: cannot remove 'qr_code_test_subparts_vgg16.tar.gz': No such file or directory
# rm: cannot remove 'test_results/*': No such file or directory
# test_results/
# test_results/qr_code_fip_test_67.png
# test_results/qr_code_fip_test_3.png
# test_results/qr_code_fip_test_12.png
# test_results/qr_code_fip_test_44.png
# test_results/qr_code_fip_test_84.png
# test_results/qr_code_fip_test_13.png
# test_results/qr_code_fip_test_39.png
# test_results/qr_code_fip_test_24.png
# test_results/qr_code_fip_test_54.png
# test_results/qr_code_fip_test_96.png
# test_results/qr_code_fip_test_94.png
# test_results/qr_code_fip_test_86.png
# test_results/qr_code_fip_test_98.png
# test_results/qr_code_fip_test_79.png
# test_results/qr_code_fip_test_9.png
# test_results/qr_code_fip_test_15.png
# test_results/qr_code_fip_test_83.png
# test_results/qr_code_fip_test_93.png
# test_results/qr_code_fip_test_37.png
# test_results/qr_code_fip_test_34.png
# test_results/qr_code_fip_test_51.png
# test_results/qr_code_fip_test_80.png
# test_results/qr_code_fip_test_60.png
# test_results/qr_code_fip_test_14.png
# test_results/qr_code_fip_test_62.png
# test_results/qr_code_fip_test_52.png
# test_results/qr_code_fip_test_70.png
# test_results/qr_code_fip_test_56.png
# test_results/qr_code_fip_test_16.png
# test_results/qr_code_fip_test_0.png
# test_results/qr_code_fip_test_71.png
# test_results/qr_code_fip_test_8.png
# test_results/qr_code_fip_test_2.png
# test_results/qr_code_fip_test_28.png
# test_results/qr_code_fip_test_36.png
# test_results/qr_code_fip_test_40.png
# test_results/qr_code_fip_test_73.png
# test_results/qr_code_fip_test_87.png
# test_results/qr_code_fip_test_85.png
# test_results/qr_code_fip_test_47.png
# test_results/qr_code_fip_test_81.png
# test_results/qr_code_fip_test_58.png
# test_results/qr_code_fip_test_82.png
# test_results/qr_code_fip_test_72.png
# test_results/qr_code_fip_test_11.png
# test_results/qr_code_fip_test_25.png
# test_results/qr_code_fip_test_61.png
# test_results/qr_code_fip_test_6.png
# test_results/qr_code_fip_test_63.png
# test_results/qr_code_fip_test_89.png
# test_results/qr_code_fip_test_91.png
# test_results/qr_code_fip_test_29.png
# test_results/qr_code_fip_test_75.png
# test_results/qr_code_fip_test_78.png
# test_results/qr_code_fip_test_65.png
# test_results/qr_code_fip_test_5.png
# test_results/qr_code_fip_test_7.png
# test_results/qr_code_fip_test_18.png
# test_results/qr_code_fip_test_45.png
# test_results/qr_code_fip_test_38.png
# test_results/qr_code_fip_test_50.png
# test_results/qr_code_fip_test_22.png
# test_results/qr_code_fip_test_48.png
# test_results/qr_code_fip_test_59.png
# test_results/qr_code_fip_test_77.png
# test_results/qr_code_fip_test_41.png
# test_results/qr_code_fip_test_76.png
# test_results/qr_code_fip_test_4.png
# test_results/qr_code_fip_test_20.png
# test_results/qr_code_fip_test_88.png
# test_results/qr_code_fip_test_43.png
# test_results/qr_code_fip_test_90.png
# test_results/qr_code_fip_test_10.png
# test_results/qr_code_fip_test_68.png
# test_results/qr_code_fip_test_74.png
# test_results/qr_code_fip_test_33.png
# test_results/qr_code_fip_test_97.png
# test_results/qr_code_fip_test_53.png
# test_results/qr_code_fip_test_35.png
# test_results/qr_code_fip_test_92.png
# test_results/qr_code_fip_test_30.png
# test_results/qr_code_fip_test_99.png
# test_results/qr_code_fip_test_26.png
# test_results/qr_code_fip_test_55.png
# test_results/qr_code_fip_test_42.png
# test_results/qr_code_fip_test_49.png
# test_results/qr_code_fip_test_66.png
# test_results/qr_code_fip_test_1.png
# test_results/qr_code_fip_test_32.png
# test_results/qr_code_fip_test_27.png
# test_results/qr_code_fip_test_23.png
# test_results/qr_code_fip_test_19.png
# test_results/qr_code_fip_test_64.png
# test_results/qr_code_fip_test_69.png
# test_results/qr_code_fip_test_17.png
# test_results/qr_code_fip_test_95.png
# test_results/qr_code_fip_test_57.png
# test_results/qr_code_fip_test_46.png
# test_results/qr_code_fip_test_21.png
# test_results/qr_code_fip_test_31.png
