# qr_codes/images/5272460338.jpg
# qr_codes/images/4058130706.jpg
# qr_codes/images/4397152402.jpg
# qr_codes/images/5023713525.jpg
# qr_codes/images/2686042700.jpg
# qr_codes/images/2457868748.jpg
# qr_codes/images/0179583169.jpg
# qr_codes/images/4777185721.jpg
# qr_codes/images/3738757335.jpg
# qr_codes/images/4949259371.jpg
# qr_codes/images/4441975297.jpg
# qr_codes/images/5093857705.jpg
# qr_codes/images/4747076605.jpg
# qr_codes/images/5036470874.jpg
# qr_codes/images/2685220165.jpg
# qr_codes/fips_all.csv
# qr_codes/fips_train.csv
# qr_codes/qr_codes_train.csv
# qr_codes/qr_codes_all.csv
# qr_codes/fips_test.csv
# qr_codes/qr_codes_test.csv
# qr_codes/qr_codes_valid.csv

# %%
from ppn_keras.networks.ssd_ppn_resnet50 import SSD_PPN_ResNet50

network = SSD_PPN_ResNet50(class_labels = ['qr_code', 'fip'],
                            input_shape = (480,480,3))

network.model.summary()
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 3s 0us/step
# Tensor("activation_40/Relu:0", shape=(?, 30, 30, 1024), dtype=float32)
# Tensor("max_pool_1/MaxPool:0", shape=(?, 15, 15, 1024), dtype=float32)
# Tensor("max_pool_2/MaxPool:0", shape=(?, 8, 8, 1024), dtype=float32)
# Tensor("max_pool_3/MaxPool:0", shape=(?, 4, 4, 1024), dtype=float32)
# Tensor("max_pool_4/MaxPool:0", shape=(?, 2, 2, 1024), dtype=float32)
# Tensor("max_pool_5/MaxPool:0", shape=(?, 1, 1, 1024), dtype=float32)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 480, 480, 3)  0
# __________________________________________________________________________________________________
# preprocess (Lambda)             (None, 480, 480, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 486, 486, 3)  0           preprocess[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 240, 240, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 240, 240, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 240, 240, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 242, 242, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 64) 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 120, 120, 64) 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 120, 120, 64) 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 120, 120, 64) 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 120, 120, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 120, 120, 64) 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 120, 120, 64) 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 120, 120, 256 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 120, 120, 256 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 120, 120, 256 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 120, 120, 256 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 120, 120, 256 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 120, 120, 256 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 120, 120, 64) 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 120, 120, 64) 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 120, 120, 64) 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 120, 120, 64) 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 120, 120, 64) 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 120, 120, 64) 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 120, 120, 256 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 120, 120, 256 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 120, 120, 256 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 120, 120, 256 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 120, 120, 64) 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 120, 120, 64) 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 120, 120, 64) 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 120, 120, 64) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 120, 120, 64) 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 120, 120, 64) 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 120, 120, 256 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 120, 120, 256 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 120, 120, 256 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 120, 120, 256 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 60, 60, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 60, 60, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 60, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 60, 60, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 60, 60, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 60, 60, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 60, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 60, 60, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 60, 60, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 60, 60, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 60, 60, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 60, 60, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 60, 60, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 60, 60, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 60, 60, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 60, 60, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 60, 60, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 60, 60, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 60, 60, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 60, 60, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 60, 60, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 60, 60, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 60, 60, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 60, 60, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 60, 60, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 60, 60, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 60, 60, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 30, 30, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 30, 30, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 30, 30, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 30, 30, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 30, 30, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 30, 30, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 30, 30, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 30, 30, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 30, 30, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 30, 30, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 30, 30, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 30, 30, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 30, 30, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 30, 30, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 30, 30, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 30, 30, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 30, 30, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 30, 30, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 30, 30, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 30, 30, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 30, 30, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 30, 30, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 30, 30, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 30, 30, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 30, 30, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 30, 30, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 30, 30, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 30, 30, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 30, 30, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 30, 30, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 30, 30, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 30, 30, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 30, 30, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# max_pool_1 (MaxPooling2D)       (None, 15, 15, 1024) 0           activation_40[0][0]
# __________________________________________________________________________________________________
# max_pool_2 (MaxPooling2D)       (None, 8, 8, 1024)   0           max_pool_1[0][0]
# __________________________________________________________________________________________________
# max_pool_3 (MaxPooling2D)       (None, 4, 4, 1024)   0           max_pool_2[0][0]
# __________________________________________________________________________________________________
# max_pool_4 (MaxPooling2D)       (None, 2, 2, 1024)   0           max_pool_3[0][0]
# __________________________________________________________________________________________________
# max_pool_5 (MaxPooling2D)       (None, 1, 1, 1024)   0           max_pool_4[0][0]
# __________________________________________________________________________________________________
# shared_conv (Conv2D)            multiple             524800      activation_40[0][0]
#                                                                  max_pool_1[0][0]
#                                                                  max_pool_2[0][0]
#                                                                  max_pool_3[0][0]
#                                                                  max_pool_4[0][0]
#                                                                  max_pool_5[0][0]
# __________________________________________________________________________________________________
# box_classifier (Conv2D)         multiple             82962       shared_conv[0][0]
#                                                                  shared_conv[1][0]
#                                                                  shared_conv[2][0]
#                                                                  shared_conv[3][0]
#                                                                  shared_conv[4][0]
#                                                                  shared_conv[5][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 5400, 3)      0           box_classifier[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1350, 3)      0           box_classifier[1][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 384, 3)       0           box_classifier[2][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 96, 3)        0           box_classifier[3][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 24, 3)        0           box_classifier[4][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 6, 3)         0           box_classifier[5][0]
# __________________________________________________________________________________________________
# box_regressor (Conv2D)          multiple             110616      shared_conv[0][0]
#                                                                  shared_conv[1][0]
#                                                                  shared_conv[2][0]
#                                                                  shared_conv[3][0]
#                                                                  shared_conv[4][0]
#                                                                  shared_conv[5][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 5400, 3)      0           reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 1350, 3)      0           reshape_3[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 384, 3)       0           reshape_5[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 96, 3)        0           reshape_7[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 24, 3)        0           reshape_9[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 6, 3)         0           reshape_11[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 5400, 4)      0           box_regressor[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1350, 4)      0           box_regressor[1][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 384, 4)       0           box_regressor[2][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 96, 4)        0           box_regressor[3][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 24, 4)        0           box_regressor[4][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 6, 4)         0           box_regressor[5][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7260, 3)      0           activation_50[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_52[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 7260, 4)      0           reshape_2[0][0]
#                                                                  reshape_4[0][0]
#                                                                  reshape_6[0][0]
#                                                                  reshape_8[0][0]
#                                                                  reshape_10[0][0]
#                                                                  reshape_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 7260, 7)      0           concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
# ==================================================================================================
# Total params: 9,307,562
# Trainable params: 9,276,970
# Non-trainable params: 30,592
# __________________________________________________________________________________________________

# %%
from imgaug import augmenters as iaa
import numpy as np

# Sometimes(0.5, ...) applies the given augmenter in 50% of all cases,
# e.g. Sometimes(0.5, GaussianBlur(0.3)) would blur roughly every second
# image.
sometimes = lambda aug: iaa.Sometimes(0.5, aug)

# Define our sequence of augmentation steps that will be applied to every image.
augmentation_seq = iaa.Sequential(
    [
        #
        # Apply the following augmenters to most images.
        #
        iaa.Fliplr(0.5), # horizontally flip 50% of all images
        iaa.Flipud(0.2), # vertically flip 20% of all images

        # crop some of the images by 0-10% of their height/width
        sometimes(iaa.Crop(percent=(0, 0.1))),

        # Apply affine transformations to some of the images
        # - scale to 80-120% of image height/width (each axis independently)
        # - translate by -20 to +20 relative to height/width (per axis)
        # - rotate by -45 to +45 degrees
        # - shear by -16 to +16 degrees
        # - order: use nearest neighbour or bilinear interpolation (fast)
        # - mode: use any available mode to fill newly created pixels
        #         see API or scikit-image for which modes are available
        # - cval: if the mode is constant, then use a random brightness
        #         for the newly created pixels (e.g. sometimes black,
        #         sometimes white)
        sometimes(iaa.Affine(
            scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            rotate=(-45, 45),
            shear=(-16, 16),
            order=[0, 1],
            cval=(0, 255),
            mode=ia.ALL
        )),

        #
        # Execute 0 to 5 of the following (less important) augmenters per
        # image. Don't execute all of them, as that would often be way too
        # strong.
        #
        iaa.SomeOf((0, 5),
            [
                # Convert some images into their superpixel representation,
                # sample between 20 and 200 superpixels per image, but do
                # not replace all superpixels with their average, only
                # some of them (p_replace).
                sometimes(
                    iaa.Superpixels(
                        p_replace=(0, 1.0),
                        n_segments=(20, 200)
                    )
                ),

                # Blur each image with varying strength using
                # gaussian blur (sigma between 0 and 3.0),
                # average/uniform blur (kernel size between 2x2 and 7x7)
                # median blur (kernel size between 3x3 and 11x11).
                iaa.OneOf([
                    iaa.GaussianBlur((0, 3.0)),
                    iaa.AverageBlur(k=(2, 7)),
                    iaa.MedianBlur(k=(3, 11)),
                ]),

                # Sharpen each image, overlay the result with the original
                # image using an alpha between 0 (no sharpening) and 1
                # (full sharpening effect).
                iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)),

                # Same as sharpen, but for an embossing effect.
                iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)),

                # Search in some images either for all edges or for
                # directed edges. These edges are then marked in a black
                # and white image and overlayed with the original image
                # using an alpha of 0 to 0.7.
                sometimes(iaa.OneOf([
                    iaa.EdgeDetect(alpha=(0, 0.7)),
                    iaa.DirectedEdgeDetect(
                        alpha=(0, 0.7), direction=(0.0, 1.0)
                    ),
                ])),

                # Add gaussian noise to some images.
                # In 50% of these cases, the noise is randomly sampled per
                # channel and pixel.
                # In the other 50% of all cases it is sampled once per
                # pixel (i.e. brightness change).
                iaa.AdditiveGaussianNoise(
                    loc=0, scale=(0.0, 0.05*255), per_channel=0.5
                ),

                # Either drop randomly 1 to 10% of all pixels (i.e. set
                # them to black) or drop them on an image with 2-5% percent
                # of the original size, leading to large dropped
                # rectangles.
                iaa.OneOf([
                    iaa.Dropout((0.01, 0.1), per_channel=0.5),
                    iaa.CoarseDropout(
                        (0.03, 0.15), size_percent=(0.02, 0.05),
                        per_channel=0.2
                    ),
                ]),

                # Invert each image's chanell with 5% probability.
                # This sets each pixel value v to 255-v.
                iaa.Invert(0.05, per_channel=True), # invert color channels

                # Add a value of -10 to 10 to each pixel.
                iaa.Add((-10, 10), per_channel=0.5),

                # Change brightness of images (50-150% of original value).
                iaa.Multiply((0.5, 1.5), per_channel=0.5),

                # Improve or worsen the contrast of images.
                iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5),

                # Convert each image to grayscale and then overlay the
                # result with the original with random alpha. I.e. remove
                # colors with varying strengths.
                iaa.Grayscale(alpha=(0.0, 1.0)),

                # In some images move pixels locally around (with random
                # strengths).
                sometimes(
                    iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)
                ),

                # In some images distort local areas with varying strength.
                sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05)))
            ],
            # do all of the above augmentations in random order
            random_order=True
        )
    ],
    # do all of the above augmentations in random order
    random_order=True
)

# %%
import pandas as pd

train_qr_codes = pd.read_csv('qr_codes_train.csv', dtype={'image_id': str})
valid_qr_codes = pd.read_csv('qr_codes_valid.csv', dtype={'image_id': str})

train_fips = pd.read_csv('fips_train.csv', dtype={'image_id': str})
valid_fips = pd.read_csv('fips_valid.csv', dtype={'image_id': str})

train = pd.concat([train_qr_codes, train_fips], axis = 0, ignore_index = True)
valid = pd.concat([valid_qr_codes, valid_fips], axis = 0, ignore_index = True)


from ppn_keras.batch_generator import BatchGenerator

batch_generator_train = BatchGenerator(network)
batch_generator_valid = BatchGenerator(network)

batch_generator_train.add_data(dataset = train, images_dir='images')
batch_generator_valid.add_data(dataset = valid, images_dir='images')

batch_size = 8

valid_generator, valid_size = batch_generator_valid.get_generator(batch_size = 1, shuffle = False, augmentation = False, encode_output = False)
valid_X, valid_y = [], []

for _ in range(valid_size):
  batch_X, batch_y = next(valid_generator)
  valid_X.append(batch_X[0])
  valid_y.append(batch_y[0])
  
valid_X = np.array(valid_X)

train_generator, train_size = batch_generator_train.get_generator(batch_size=batch_size, shuffle=True, augmentation=augmentation_seq, encode_output=True)
valid_generator, valid_size = batch_generator_valid.get_generator(batch_size = batch_size, shuffle = False, augmentation = False, encode_output = True)

print('%d training images' % train_size)
print('%d validation images' % valid_size)

train_generator_vis, _ = batch_generator_train.get_generator(batch_size=1, shuffle=True, augmentation=augmentation_seq, encode_output=False)

batch_X, batch_y = next(train_generator)
print(batch_X.shape)
print(batch_y.shape)

fig = plt.figure(figsize=(20,20))

for i in range(6):
  batch_X, batch_y = next(train_generator_vis)
  img, boxes = batch_X[0], batch_y[0]
  
  img = boxes.draw_on_image(img, thickness=6)
  
  ax = fig.add_subplot(3, 2, i+1)
  ax.imshow(img)
  
print(batch_y)
# Out:
# Preprocessing Dataset: 100%|██████████| 3714/3714 [00:35<00:00, 104.53it/s]
# Preprocessing Dataset: 100%|██████████| 552/552 [00:06<00:00, 91.88it/s]
# 567 training images
# 100 validation images
# (8, 480, 480, 3)
# (8, 7260, 7)
# [BoundingBoxesOnImage([BoundingBox(x1=106.1441, y1=158.5861, x2=201.2559, y2=259.0828, label=qr_code), BoundingBox(x1=108.0090, y1=234.7731, x2=131.0876, y2=259.0828, label=fip), BoundingBox(x1=106.1441, y1=160.0898, x2=129.4558, y2=184.6501, label=fip), BoundingBox(x1=175.6130, y1=158.5861, x2=198.9247, y2=182.8958, label=fip)], shape=(480, 480, 3))]

# %%
import keras
from ppn_keras import metrics

network.model.compile(
  optimizer = keras.optimizers.Adam(1e-4, decay=1e-4),
  loss = metrics.get_ppn_loss()
)

# %%
from keras.callbacks import Callback, ModelCheckpoint
from ppn_keras.encode_decode_output import output_decoder

class PrintMetricsOnEnd(Callback):
  def __init__(self):
    super(PrintMetricsOnEnd, self).__init__()
    
  def on_epoch_end(self, epoch, logs=None):
    logs = logs or {}
    for k in self.params['metrics']:
      if k in logs:
        print('%s: %.10f' % (k, logs[k]))
    print()
    
class EvaluateValidMeanAP(Callback):
  def __init__(self):
    super(EvaluateValidMeanAP, self).__init__()
    self.best_mAP = 0
    
  def on_epoch_end(self, epoch, logs=None):
    y_pred = network.model.predict(valid_X, batch_size = batch_size, verbose = 0)
    y_pred = output_decoder(y_pred, network, nms_threshold = 0.3)
    
    AP = metrics.per_class_AP(valid_y, y_pred, classes = ['qr_code', 'fip'])
    print('Validation meanAP:', AP)
    print()
    
    if AP[0] > self.best_mAP:
      self.best_mAP = AP[0]
      network.model.save('ppn_resnet50_qr_codes_fips.%03d-%.6f_mAP.hdf5' % (epoch, AP[0]))

# !rm ppn_resnet50_qr_codes_fips.*

network.model.fit_generator(train_generator,
                            steps_per_epoch = 50,
                            epochs = 100,
                            validation_data = valid_generator,
                            validation_steps = int(np.floor(valid_size / batch_size)),
                            verbose = 1,
                            max_queue_size = 200,
                            callbacks = [
                                PrintMetricsOnEnd(),
                                EvaluateValidMeanAP()
                            ])
# Out:
# rm: cannot remove 'ppn_resnet50_qr_codes_fips.*': No such file or directory
# Epoch 1/100
# 50/50 [==============================] - 159s 3s/step - loss: 0.0755 - val_loss: 0.0133
# loss: 0.0754806812
# val_loss: 0.0133320766
#
# Validation meanAP: [0.0011618162462658677, 0.0]
#
# Epoch 2/100
# 50/50 [==============================] - 56s 1s/step - loss: 0.0132 - val_loss: 0.0088
# loss: 0.0131658149
# val_loss: 0.0087678590
#
# Validation meanAP: [0.006825213911749494, 0.00040749796251018743]
#
# Epoch 3/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0099 - val_loss: 0.0071
# loss: 0.0099069516
# val_loss: 0.0070607928
#
# Validation meanAP: [0.008781624957516509, 0.0009046454767726161]
#
# Epoch 4/100
# 50/50 [==============================] - 84s 2s/step - loss: 0.0086 - val_loss: 0.0063
# loss: 0.0085881958
# val_loss: 0.0063013146
#
# Validation meanAP: [0.011655494153945043, 0.004369808792022126]
#
# Epoch 5/100
# 50/50 [==============================] - 76s 2s/step - loss: 0.0073 - val_loss: 0.0051
# loss: 0.0073069190
# val_loss: 0.0051066415
#
# Validation meanAP: [0.02505251228583058, 0.004086145878265663]
#
# Epoch 6/100
# 50/50 [==============================] - 102s 2s/step - loss: 0.0063 - val_loss: 0.0045
# loss: 0.0063014254
# val_loss: 0.0045487620
#
# Validation meanAP: [0.029146226631349553, 0.010149040942217335]
#
# Epoch 7/100
# 50/50 [==============================] - 81s 2s/step - loss: 0.0061 - val_loss: 0.0041
# loss: 0.0061330797
# val_loss: 0.0040834712
#
# Validation meanAP: [0.046975653602191754, 0.018368926581942578]
#
# Epoch 8/100
# 50/50 [==============================] - 82s 2s/step - loss: 0.0049 - val_loss: 0.0037
# loss: 0.0049342362
# val_loss: 0.0036835333
#
# Validation meanAP: [0.037128661952777246, 0.03322920442293887]
#
# Epoch 9/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0057 - val_loss: 0.0035
# loss: 0.0057282089
# val_loss: 0.0034520062
#
# Validation meanAP: [0.03232037412192329, 0.018475436802972797]
#
# Epoch 10/100
# 50/50 [==============================] - 77s 2s/step - loss: 0.0042 - val_loss: 0.0032
# loss: 0.0042139126
# val_loss: 0.0032100263
#
# Validation meanAP: [0.051013451126298764, 0.04295312394362934]
#
# Epoch 11/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0045 - val_loss: 0.0030
# loss: 0.0044937618
# val_loss: 0.0029865327
#
# Validation meanAP: [0.08202115860255076, 0.03426118394532077]
#
# Epoch 12/100
# 50/50 [==============================] - 88s 2s/step - loss: 0.0044 - val_loss: 0.0029
# loss: 0.0044177053
# val_loss: 0.0028687572
#
# Validation meanAP: [0.06801519902097931, 0.045385585314398194]
#
# Epoch 13/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0042 - val_loss: 0.0026
# loss: 0.0041591519
# val_loss: 0.0026325948
#
# Validation meanAP: [0.053733178065088316, 0.05902934229814538]
#
# Epoch 14/100
# 50/50 [==============================] - 88s 2s/step - loss: 0.0035 - val_loss: 0.0024
# loss: 0.0034891160
# val_loss: 0.0024407886
#
# Validation meanAP: [0.07310059388963519, 0.05194252339640291]
#
# Epoch 15/100
# 50/50 [==============================] - 93s 2s/step - loss: 0.0034 - val_loss: 0.0023
# loss: 0.0033761976
# val_loss: 0.0023124898
#
# Validation meanAP: [0.07820061383865246, 0.07094128019116605]
#
# Epoch 16/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0036 - val_loss: 0.0022
# loss: 0.0035671560
# val_loss: 0.0022184686
#
# Validation meanAP: [0.09696885380790347, 0.04435626426827108]
#
# Epoch 17/100
# 50/50 [==============================] - 88s 2s/step - loss: 0.0035 - val_loss: 0.0022
# loss: 0.0034968950
# val_loss: 0.0022288205
#
# Validation meanAP: [0.13347348698570516, 0.10788772970490672]
#
# Epoch 18/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0031 - val_loss: 0.0020
# loss: 0.0031166820
# val_loss: 0.0020227446
#
# Validation meanAP: [0.13314160262714758, 0.09819214561557528]
#
# Epoch 19/100
# 50/50 [==============================] - 81s 2s/step - loss: 0.0030 - val_loss: 0.0020
# loss: 0.0029696773
# val_loss: 0.0020011703
#
# Validation meanAP: [0.1704520543639254, 0.11618064858277213]
#
# Epoch 20/100
# 50/50 [==============================] - 77s 2s/step - loss: 0.0035 - val_loss: 0.0020
# loss: 0.0034961848
# val_loss: 0.0019597787
#
# Validation meanAP: [0.1859345671713995, 0.12491642699190508]
#
# Epoch 21/100
# 50/50 [==============================] - 84s 2s/step - loss: 0.0029 - val_loss: 0.0018
# loss: 0.0029139303
# val_loss: 0.0018291906
#
# Validation meanAP: [0.20663585054592742, 0.13537676810937008]
#
# Epoch 22/100
# 50/50 [==============================] - 101s 2s/step - loss: 0.0032 - val_loss: 0.0018
# loss: 0.0031556811
# val_loss: 0.0018038079
#
# Validation meanAP: [0.12881346179104525, 0.09132472788898062]
#
# Epoch 23/100
# 50/50 [==============================] - 86s 2s/step - loss: 0.0026 - val_loss: 0.0017
# loss: 0.0026154966
# val_loss: 0.0017218181
#
# Validation meanAP: [0.1337311893053865, 0.1122734045234304]
#
# Epoch 24/100
# 50/50 [==============================] - 84s 2s/step - loss: 0.0030 - val_loss: 0.0017
# loss: 0.0030028142
# val_loss: 0.0017189533
#
# Validation meanAP: [0.13903920525428187, 0.16181428726562327]
#
# Epoch 25/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0031 - val_loss: 0.0016
# loss: 0.0030675330
# val_loss: 0.0016227823
#
# Validation meanAP: [0.18636842406124607, 0.15494493427952338]
#
# Epoch 26/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0028 - val_loss: 0.0015
# loss: 0.0027571267
# val_loss: 0.0015494444
#
# Validation meanAP: [0.2058418119583567, 0.16204914707459922]
#
# Epoch 27/100
# 50/50 [==============================] - 72s 1s/step - loss: 0.0026 - val_loss: 0.0016
# loss: 0.0025662788
# val_loss: 0.0015747622
#
# Validation meanAP: [0.22718170883734942, 0.1542119813820927]
#
# Epoch 28/100
# 50/50 [==============================] - 82s 2s/step - loss: 0.0027 - val_loss: 0.0016
# loss: 0.0027317611
# val_loss: 0.0015974594
#
# Validation meanAP: [0.2014428703358481, 0.14724310098281818]
#
# Epoch 29/100
# 50/50 [==============================] - 78s 2s/step - loss: 0.0028 - val_loss: 0.0016
# loss: 0.0027890944
# val_loss: 0.0016034698
#
# Validation meanAP: [0.2662700755408868, 0.1420932749889428]
#
# Epoch 30/100
# 50/50 [==============================] - 83s 2s/step - loss: 0.0026 - val_loss: 0.0015
# loss: 0.0025805505
# val_loss: 0.0014957512
#
# Validation meanAP: [0.25542183883740655, 0.16650645732360844]
#
# Epoch 31/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0025 - val_loss: 0.0015
# loss: 0.0024817470
# val_loss: 0.0014749952
#
# Validation meanAP: [0.2894275778365799, 0.1443616489003907]
#
# Epoch 32/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0026 - val_loss: 0.0015
# loss: 0.0026213292
# val_loss: 0.0015007457
#
# Validation meanAP: [0.19035985712355585, 0.16615656865080788]
#
# Epoch 33/100
# 50/50 [==============================] - 67s 1s/step - loss: 0.0028 - val_loss: 0.0014
# loss: 0.0027724035
# val_loss: 0.0014351545
#
# Validation meanAP: [0.24024787206639525, 0.1319246868192071]
#
# Epoch 34/100
# 50/50 [==============================] - 76s 2s/step - loss: 0.0024 - val_loss: 0.0014
# loss: 0.0023631008
# val_loss: 0.0013515490
#
# Validation meanAP: [0.21679928134692433, 0.17282312733167723]
#
# Epoch 35/100
# 50/50 [==============================] - 98s 2s/step - loss: 0.0025 - val_loss: 0.0014
# loss: 0.0025345838
# val_loss: 0.0013717352
#
# Validation meanAP: [0.30338215458020934, 0.18995838298546197]
#
# Epoch 36/100
# 50/50 [==============================] - 86s 2s/step - loss: 0.0025 - val_loss: 0.0013
# loss: 0.0024947013
# val_loss: 0.0013490571
#
# Validation meanAP: [0.25671774492100385, 0.1786895012237047]
#
# Epoch 37/100
# 50/50 [==============================] - 86s 2s/step - loss: 0.0022 - val_loss: 0.0013
# loss: 0.0022223612
# val_loss: 0.0013315935
#
# Validation meanAP: [0.2554042120702148, 0.18404830983815695]
#
# Epoch 38/100
# 50/50 [==============================] - 78s 2s/step - loss: 0.0025 - val_loss: 0.0013
# loss: 0.0024778779
# val_loss: 0.0013380327
#
# Validation meanAP: [0.36010363314804483, 0.19752535234617025]
#
# Epoch 39/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0022 - val_loss: 0.0013
# loss: 0.0022152883
# val_loss: 0.0012836464
#
# Validation meanAP: [0.3417904010744858, 0.22219007616189426]
#
# Epoch 40/100
# 50/50 [==============================] - 87s 2s/step - loss: 0.0021 - val_loss: 0.0013
# loss: 0.0021102913
# val_loss: 0.0013130757
#
# Validation meanAP: [0.3027612814169661, 0.2164407743601786]
#
# Epoch 41/100
# 50/50 [==============================] - 74s 1s/step - loss: 0.0025 - val_loss: 0.0013
# loss: 0.0024982978
# val_loss: 0.0013288125
#
# Validation meanAP: [0.31966398532819207, 0.15807812028051307]
#
# Epoch 42/100
# 50/50 [==============================] - 71s 1s/step - loss: 0.0020 - val_loss: 0.0013
# loss: 0.0019898972
# val_loss: 0.0012898156
#
# Validation meanAP: [0.30069083928378804, 0.1636679143656408]
#
# Epoch 43/100
# 50/50 [==============================] - 81s 2s/step - loss: 0.0019 - val_loss: 0.0013
# loss: 0.0019184304
# val_loss: 0.0013361540
#
# Validation meanAP: [0.2503259744096834, 0.1953526319508333]
#
# Epoch 44/100
# 50/50 [==============================] - 75s 2s/step - loss: 0.0022 - val_loss: 0.0012
# loss: 0.0022264170
# val_loss: 0.0012375230
#
# Validation meanAP: [0.344077099285703, 0.2013103795904911]
#
# Epoch 45/100
# 50/50 [==============================] - 68s 1s/step - loss: 0.0024 - val_loss: 0.0014
# loss: 0.0024257436
# val_loss: 0.0013928016
#
# Validation meanAP: [0.3985628252966434, 0.2055970829925255]
#
# Epoch 46/100
# 50/50 [==============================] - 89s 2s/step - loss: 0.0022 - val_loss: 0.0013
# loss: 0.0021786538
# val_loss: 0.0013110715
#
# Validation meanAP: [0.34887819671377135, 0.19875680231642828]
#
# Epoch 47/100
# 50/50 [==============================] - 83s 2s/step - loss: 0.0022 - val_loss: 0.0013
# loss: 0.0022161250
# val_loss: 0.0012675107
#
# Validation meanAP: [0.4817344153059676, 0.20991587516867044]
#
# Epoch 48/100
# 50/50 [==============================] - 72s 1s/step - loss: 0.0019 - val_loss: 0.0012
# loss: 0.0019437164
# val_loss: 0.0012276128
#
# Validation meanAP: [0.44658286823677595, 0.21188585252728648]
#
# Epoch 49/100
# 50/50 [==============================] - 88s 2s/step - loss: 0.0022 - val_loss: 0.0013
# loss: 0.0022437762
# val_loss: 0.0012829817
#
# Validation meanAP: [0.3498147366600382, 0.19936246987456127]
#
# Epoch 50/100
# 50/50 [==============================] - 84s 2s/step - loss: 0.0019 - val_loss: 0.0013
# loss: 0.0019001511
# val_loss: 0.0012782364
#
# Validation meanAP: [0.366979817036159, 0.22137820789685508]
#
# Epoch 51/100
# 50/50 [==============================] - 85s 2s/step - loss: 0.0020 - val_loss: 0.0012
# loss: 0.0020120734
# val_loss: 0.0012114935
#
# Validation meanAP: [0.3620442817393412, 0.21116432325174106]
#
# Epoch 52/100
# 50/50 [==============================] - 83s 2s/step - loss: 0.0021 - val_loss: 0.0012
# loss: 0.0021074020
# val_loss: 0.0011785271
#
# Validation meanAP: [0.3922402788372056, 0.20622946867062608]
#
# Epoch 53/100
# 50/50 [==============================] - 79s 2s/step - loss: 0.0020 - val_loss: 0.0012
# loss: 0.0020386796
# val_loss: 0.0011786377
#
# Validation meanAP: [0.37634023706244535, 0.20622902027212672]
#
# Epoch 54/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0022 - val_loss: 0.0013
# loss: 0.0022022795
# val_loss: 0.0012984064
#
# Validation meanAP: [0.3353129711772203, 0.22673753702455796]
#
# Epoch 55/100
# 50/50 [==============================] - 87s 2s/step - loss: 0.0019 - val_loss: 0.0012
# loss: 0.0019229145
# val_loss: 0.0012073135
#
# Validation meanAP: [0.4004631936799855, 0.2582032965099017]
#
# Epoch 56/100
# 50/50 [==============================] - 75s 2s/step - loss: 0.0021 - val_loss: 0.0012
# loss: 0.0020706591
# val_loss: 0.0012442962
#
# Validation meanAP: [0.43318213269096995, 0.1973434615810945]
#
# Epoch 57/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0019 - val_loss: 0.0012
# loss: 0.0019280452
# val_loss: 0.0011986383
#
# Validation meanAP: [0.4022166247157903, 0.23376376490519826]
#
# Epoch 58/100
# 50/50 [==============================] - 88s 2s/step - loss: 0.0020 - val_loss: 0.0012
# loss: 0.0019727326
# val_loss: 0.0011828555
#
# Validation meanAP: [0.38522929417146246, 0.1996289500665217]
#
# Epoch 59/100
# 50/50 [==============================] - 71s 1s/step - loss: 0.0021 - val_loss: 0.0011
# loss: 0.0020928048
# val_loss: 0.0010827167
#
# Validation meanAP: [0.39820861935596824, 0.23926822885170096]
#
# Epoch 60/100
# 50/50 [==============================] - 87s 2s/step - loss: 0.0019 - val_loss: 0.0011
# loss: 0.0019316566
# val_loss: 0.0011310546
#
# Validation meanAP: [0.44316150927716935, 0.23495068670611285]
#
# Epoch 61/100
# 50/50 [==============================] - 79s 2s/step - loss: 0.0021 - val_loss: 0.0011
# loss: 0.0021093375
# val_loss: 0.0011425467
#
# Validation meanAP: [0.33378555091239925, 0.23384905516098622]
#
# Epoch 62/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0017 - val_loss: 0.0011
# loss: 0.0017195111
# val_loss: 0.0011373893
#
# Validation meanAP: [0.4414349955636835, 0.23547187832226396]
#
# Epoch 63/100
# 50/50 [==============================] - 69s 1s/step - loss: 0.0018 - val_loss: 0.0012
# loss: 0.0017524097
# val_loss: 0.0011787963
#
# Validation meanAP: [0.5698666506019671, 0.2168391640025097]
#
# Epoch 64/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0018 - val_loss: 0.0012
# loss: 0.0017988362
# val_loss: 0.0011994144
#
# Validation meanAP: [0.47523663627017726, 0.21692352766828626]
#
# Epoch 65/100
# 50/50 [==============================] - 67s 1s/step - loss: 0.0019 - val_loss: 0.0012
# loss: 0.0019064630
# val_loss: 0.0011978809
#
# Validation meanAP: [0.5209289962676666, 0.2219943117996352]
#
# Epoch 66/100
# 50/50 [==============================] - 69s 1s/step - loss: 0.0019 - val_loss: 0.0012
# loss: 0.0018520752
# val_loss: 0.0011917628
#
# Validation meanAP: [0.4187613783756411, 0.22225691162639777]
#
# Epoch 67/100
# 50/50 [==============================] - 64s 1s/step - loss: 0.0017 - val_loss: 0.0010
# loss: 0.0017263696
# val_loss: 0.0010408610
#
# Validation meanAP: [0.43746229485192845, 0.25671703987279026]
#
# Epoch 68/100
# 50/50 [==============================] - 76s 2s/step - loss: 0.0018 - val_loss: 0.0010
# loss: 0.0017826273
# val_loss: 0.0010375695
#
# Validation meanAP: [0.5328712014518062, 0.2358103416517444]
#
# Epoch 69/100
# 50/50 [==============================] - 76s 2s/step - loss: 0.0019 - val_loss: 0.0011
# loss: 0.0019250247
# val_loss: 0.0011197173
#
# Validation meanAP: [0.4753661275182279, 0.23306632449291248]
#
# Epoch 70/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0020 - val_loss: 0.0012
# loss: 0.0020281813
# val_loss: 0.0011587198
#
# Validation meanAP: [0.5787697609742487, 0.2368801263177911]
#
# Epoch 71/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0020 - val_loss: 0.0011
# loss: 0.0019900332
# val_loss: 0.0011421817
#
# Validation meanAP: [0.4965362306596507, 0.2198064308229345]
#
# Epoch 72/100
# 50/50 [==============================] - 68s 1s/step - loss: 0.0021 - val_loss: 0.0012
# loss: 0.0021376560
# val_loss: 0.0011904604
#
# Validation meanAP: [0.4808061610123936, 0.22785183179583604]
#
# Epoch 73/100
# 50/50 [==============================] - 79s 2s/step - loss: 0.0018 - val_loss: 0.0010
# loss: 0.0018220531
# val_loss: 0.0010401916
#
# Validation meanAP: [0.5332738635743978, 0.24706670880530915]
#
# Epoch 74/100
# 50/50 [==============================] - 69s 1s/step - loss: 0.0017 - val_loss: 0.0011
# loss: 0.0017318330
# val_loss: 0.0010827575
#
# Validation meanAP: [0.5080519512293911, 0.23990214102401897]
#
# Epoch 75/100
# 50/50 [==============================] - 66s 1s/step - loss: 0.0014 - val_loss: 0.0010
# loss: 0.0014465895
# val_loss: 0.0010349943
#
# Validation meanAP: [0.5635786155744592, 0.22301762464560415]
#
# Epoch 76/100
# 50/50 [==============================] - 74s 1s/step - loss: 0.0016 - val_loss: 0.0010
# loss: 0.0016483118
# val_loss: 0.0010127236
#
# Validation meanAP: [0.5166756271828761, 0.24409620533288234]
#
# Epoch 77/100
# 50/50 [==============================] - 67s 1s/step - loss: 0.0018 - val_loss: 0.0010
# loss: 0.0017860238
# val_loss: 0.0010217821
#
# Validation meanAP: [0.5112795864483397, 0.2715517531522733]
#
# Epoch 78/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0019 - val_loss: 0.0011
# loss: 0.0019104686
# val_loss: 0.0011371101
#
# Validation meanAP: [0.5709410946263901, 0.24446366165993716]
#
# Epoch 79/100
# 50/50 [==============================] - 66s 1s/step - loss: 0.0019 - val_loss: 0.0011
# loss: 0.0018844101
# val_loss: 0.0011159490
#
# Validation meanAP: [0.5676089068253469, 0.2507833455603591]
#
# Epoch 80/100
# 50/50 [==============================] - 68s 1s/step - loss: 0.0016 - val_loss: 0.0011
# loss: 0.0016091889
# val_loss: 0.0010915344
#
# Validation meanAP: [0.5071240049559801, 0.2624648244614015]
#
# Epoch 81/100
# 50/50 [==============================] - 83s 2s/step - loss: 0.0021 - val_loss: 0.0012
# loss: 0.0021297599
# val_loss: 0.0012218570
#
# Validation meanAP: [0.41064260551856124, 0.24436836488842772]
#
# Epoch 82/100
# 50/50 [==============================] - 69s 1s/step - loss: 0.0020 - val_loss: 0.0011
# loss: 0.0019688247
# val_loss: 0.0010900409
#
# Validation meanAP: [0.5464614382417354, 0.2569715840760952]
#
# Epoch 83/100
# 50/50 [==============================] - 68s 1s/step - loss: 0.0022 - val_loss: 0.0010
# loss: 0.0022202898
# val_loss: 0.0010275453
#
# Validation meanAP: [0.4985577411448783, 0.26744832240190874]
#
# Epoch 84/100
# 50/50 [==============================] - 69s 1s/step - loss: 0.0017 - val_loss: 0.0010
# loss: 0.0017388798
# val_loss: 0.0010191207
#
# Validation meanAP: [0.5959055323540003, 0.24114577786740593]
#
# Epoch 85/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0019 - val_loss: 0.0011
# loss: 0.0018901538
# val_loss: 0.0010722348
#
# Validation meanAP: [0.5564272267067083, 0.2520671066688132]
#
# Epoch 86/100
# 50/50 [==============================] - 88s 2s/step - loss: 0.0016 - val_loss: 0.0011
# loss: 0.0016279651
# val_loss: 0.0010641077
#
# Validation meanAP: [0.5601115920573632, 0.2760676181454085]
#
# Epoch 87/100
# 50/50 [==============================] - 64s 1s/step - loss: 0.0019 - val_loss: 0.0010
# loss: 0.0018983256
# val_loss: 0.0010277630
#
# Validation meanAP: [0.5157682558589939, 0.26847579669745875]
#
# Epoch 88/100
# 50/50 [==============================] - 67s 1s/step - loss: 0.0020 - val_loss: 0.0010
# loss: 0.0020185267
# val_loss: 0.0010140521
#
# Validation meanAP: [0.5560739844339838, 0.25240857313363385]
#
# Epoch 89/100
# 50/50 [==============================] - 80s 2s/step - loss: 0.0018 - val_loss: 9.7882e-04
# loss: 0.0017663453
# val_loss: 0.0009788228
#
# Validation meanAP: [0.5584079257545647, 0.2726317765769525]
#
# Epoch 90/100
# 50/50 [==============================] - 62s 1s/step - loss: 0.0015 - val_loss: 9.7883e-04
# loss: 0.0014949465
# val_loss: 0.0009788260
#
# Validation meanAP: [0.535982536128402, 0.2578793772919143]
#
# Epoch 91/100
# 50/50 [==============================] - 68s 1s/step - loss: 0.0015 - val_loss: 0.0011
# loss: 0.0015244819
# val_loss: 0.0010592126
#
# Validation meanAP: [0.5318247514236196, 0.24339592264609516]
#
# Epoch 92/100
# 50/50 [==============================] - 72s 1s/step - loss: 0.0016 - val_loss: 0.0010
# loss: 0.0015834097
# val_loss: 0.0010250504
#
# Validation meanAP: [0.5661654080412432, 0.2435006546358088]
#
# Epoch 93/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0016 - val_loss: 0.0010
# loss: 0.0016218459
# val_loss: 0.0010119729
#
# Validation meanAP: [0.5773899098494653, 0.25877901492043953]
#
# Epoch 94/100
# 50/50 [==============================] - 83s 2s/step - loss: 0.0019 - val_loss: 9.6350e-04
# loss: 0.0018888571
# val_loss: 0.0009635046
#
# Validation meanAP: [0.559442570862319, 0.25391939324782276]
#
# Epoch 95/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0016 - val_loss: 0.0010
# loss: 0.0016122839
# val_loss: 0.0010033430
#
# Validation meanAP: [0.6573568453511199, 0.25992661701163794]
#
# Epoch 96/100
# 50/50 [==============================] - 79s 2s/step - loss: 0.0016 - val_loss: 9.5979e-04
# loss: 0.0016355361
# val_loss: 0.0009597870
#
# Validation meanAP: [0.6462909634699682, 0.2596305724180308]
#
# Epoch 97/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0018 - val_loss: 0.0010
# loss: 0.0017762865
# val_loss: 0.0010179249
#
# Validation meanAP: [0.5787483043654147, 0.25547008229687346]
#
# Epoch 98/100
# 50/50 [==============================] - 82s 2s/step - loss: 0.0016 - val_loss: 0.0010
# loss: 0.0015672641
# val_loss: 0.0010329708
#
# Validation meanAP: [0.643284253980955, 0.2705318155886923]
#
# Epoch 99/100
# 50/50 [==============================] - 61s 1s/step - loss: 0.0016 - val_loss: 9.5648e-04
# loss: 0.0016220164
# val_loss: 0.0009564759
#
# Validation meanAP: [0.5759516132755239, 0.2875327653777382]
#
# Epoch 100/100
# 50/50 [==============================] - 70s 1s/step - loss: 0.0018 - val_loss: 9.8208e-04
# loss: 0.0018120673
# val_loss: 0.0009820801
#
# Validation meanAP: [0.6083421870371737, 0.2623475994222825]

# %%
# !ls -l
# Out:
# total 6706576
# -rw-r--r-- 1 root root     19652 Jan 22 19:58 fips_test.csv
# -rw-r--r-- 1 root root    124866 Jan 22 19:58 fips_train.csv
# -rw-r--r-- 1 root root     18679 Jan 22 19:58 fips_valid.csv
# drwxr-xr-x 2 root root     32768 Jan 23 01:33 images
# drwx------ 8 root root      4096 Jan 23 01:33 ppn_keras
# -rw-r--r-- 1 root root  25242808 Jan 22 20:04 ppn_mobilenet_qr_codes_fips.001-0.008121_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:05 ppn_mobilenet_qr_codes_fips.002-0.017771_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:07 ppn_mobilenet_qr_codes_fips.003-0.052732_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:08 ppn_mobilenet_qr_codes_fips.004-0.074039_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:12 ppn_mobilenet_qr_codes_fips.007-0.103989_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:13 ppn_mobilenet_qr_codes_fips.008-0.129151_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:18 ppn_mobilenet_qr_codes_fips.012-0.186549_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:21 ppn_mobilenet_qr_codes_fips.014-0.188637_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:23 ppn_mobilenet_qr_codes_fips.015-0.200360_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:24 ppn_mobilenet_qr_codes_fips.016-0.224117_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:25 ppn_mobilenet_qr_codes_fips.017-0.236193_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:27 ppn_mobilenet_qr_codes_fips.018-0.241048_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:28 ppn_mobilenet_qr_codes_fips.019-0.327341_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:36 ppn_mobilenet_qr_codes_fips.024-0.360023_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:39 ppn_mobilenet_qr_codes_fips.026-0.398514_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:43 ppn_mobilenet_qr_codes_fips.029-0.417448_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:48 ppn_mobilenet_qr_codes_fips.033-0.425031_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:51 ppn_mobilenet_qr_codes_fips.035-0.474957_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 20:59 ppn_mobilenet_qr_codes_fips.041-0.490887_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 21:01 ppn_mobilenet_qr_codes_fips.043-0.495712_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 21:02 ppn_mobilenet_qr_codes_fips.044-0.525421_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 21:04 ppn_mobilenet_qr_codes_fips.045-0.547600_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 21:13 ppn_mobilenet_qr_codes_fips.052-0.581042_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 21:20 ppn_mobilenet_qr_codes_fips.057-0.591780_mAP.hdf5
# -rw-r--r-- 1 root root  25242808 Jan 22 21
mAP.hdf5
# -rw-r--r-- 1 root root 182198784 Jan 23 00:56 ppn_vgg16_qr_codes_fips.081-0.549804_mAP.hdf5
# -rw-r--r-- 1 root root 182198784 Jan 23 01:01 ppn_vgg16_qr_codes_fips.084-0.576070_mAP.hdf5
# -rw-r--r-- 1 root root 182198784 Jan 23 01:06 ppn_vgg16_qr_codes_fips.087-0.619553_mAP.hdf5
# -rw-r--r-- 1 root root  39557120 Jan 23 01:31 qr_code_fip_test_vgg16.tar.gz
# -rw-r--r-- 1 root root  40488960 Jan 23 01:31 qr_code_fip_valid_vgg16.tar.gz
# -rw-r--r-- 1 root root      7819 Jan 23 01:33 qr_codes_test.csv
# -rw-r--r-- 1 root root     47591 Jan 23 01:33 qr_codes_train.csv
# -rw-r--r-- 1 root root      7135 Jan 23 01:33 qr_codes_valid.csv
# -rw-r--r-- 1 root root  39403520 Jan 22 22:15 qr_code_test_mobilenet.tar.gz
# -rw-r--r-- 1 root root  39557120 Jan 23 01:27 qr_code_test_vgg16.tar.gz
# drwxr-xr-x 1 root root      4096 Jan  8 17:15 sample_data
# drwxr-xr-x 2 root root      4096 Jan 23 01:31 test_results
# drwxr-xr-x 2 root root      4096 Jan 23 01:31 valid_results

# %%
from ppn_keras.encode_decode_output import output_decoder
from google.colab import files

from glob import glob
model_path = sorted(glob('ppn_resnet50_qr_codes_fips.*'))[-1]
print(model_path)

import keras
from keras.utils.generic_utils import CustomObjectScope

with CustomObjectScope({'resnet50': keras.applications.resnet50,
                        'relu6': keras.layers.ReLU(6.),
                        'ppn_loss': metrics.get_ppn_loss()}):
    model = keras.models.load_model(model_path)

#model = network.model

y_pred = model.predict(valid_X, batch_size = batch_size)
y_pred = output_decoder(y_pred, network, nms_threshold = 0.3)

print('Validation mAP:', metrics.per_class_AP(valid_y, y_pred, classes = ['qr_code', 'fip']))

for i in range(valid_size):
  img, boxes = valid_X[i], y_pred[i]

  img = boxes.draw_on_image(img, thickness=6)
  
  cv.imwrite('qr_code_fip_valid_%d.png'%i, img[..., [2,1,0]])
  
# !rm qr_code_fip_valid_resnet50.tar.gz valid_results/*
# !mkdir valid_results
# !mv qr_code_fip_valid* valid_results
# !tar -cvf qr_code_fip_valid_resnet50.tar.gz valid_results
# Out:
# ppn_resnet50_qr_codes_fips.094-0.657357_mAP.hdf5
# Validation mAP: [0.6573568453511199, 0.25992661701163794]
# mkdir: cannot create directory ‘valid_results’: File exists
# valid_results/
# valid_results/qr_code_fip_valid_79.png
# valid_results/qr_code_fip_valid_44.png
# valid_results/qr_code_fip_valid_46.png
# valid_results/qr_code_fip_valid_10.png
# valid_results/qr_code_fip_valid_35.png
# valid_results/qr_code_fip_valid_68.png
# valid_results/qr_code_fip_valid_77.png
# valid_results/qr_code_fip_valid_72.png
# valid_results/qr_code_fip_valid_5.png
# valid_results/qr_code_fip_valid_43.png
# valid_results/qr_code_fip_valid_87.png
# valid_results/qr_code_fip_valid_91.png
# valid_results/qr_code_fip_valid_49.png
# valid_results/qr_code_fip_valid_86.png
# valid_results/qr_code_fip_valid_52.png
# valid_results/qr_code_fip_valid_47.png
# valid_results/qr_code_fip_valid_59.png
# valid_results/qr_code_fip_valid_4.png
# valid_results/qr_code_fip_valid_65.png
# valid_results/qr_code_fip_valid_55.png
# valid_results/qr_code_fip_valid_25.png
# valid_results/qr_code_fip_valid_18.png
# valid_results/qr_code_fip_valid_78.png
# valid_results/qr_code_fip_valid_97.png
# valid_results/qr_code_fip_valid_31.png
# valid_results/qr_code_fip_valid_89.png
# valid_results/qr_code_fip_valid_24.png

# %%
test_qr_codes = pd.read_csv('qr_codes_test.csv', dtype={'image_id': str})
test_fips = pd.read_csv('fips_test.csv', dtype={'image_id': str})

test = pd.concat([test_qr_codes, test_fips], axis = 0, ignore_index = True)

batch_generator_test = BatchGenerator(network)
batch_generator_test.add_data(dataset = test, images_dir='images')

test_generator, test_size = batch_generator_test.get_generator(batch_size = 1, shuffle = False, augmentation = False, encode_output = False)
test_X, test_y = [], []

for _ in range(test_size):
  batch_X, batch_y = next(test_generator)
  test_X.append(batch_X[0])
  test_y.append(batch_y[0])
  
test_X = np.array(test_X)

from ppn_keras.encode_decode_output import output_decoder
from google.colab import files

from glob import glob
model_path = sorted(glob('ppn_resnet50_qr_codes_fips.*'))[-1]
print(model_path)

import keras
from keras.utils.generic_utils import CustomObjectScope

with CustomObjectScope({'resnet50': keras.applications.resnet50,
                        'relu6': keras.layers.ReLU(6.),
                        'ppn_loss': metrics.get_ppn_loss()}):
    model = keras.models.load_model(model_path)

#model = network.model

y_pred = model.predict(test_X, batch_size = batch_size)
y_pred = output_decoder(y_pred, network, nms_threshold = 0.3)

print('Test mAP:', metrics.per_class_AP(test_y, y_pred, classes = ['qr_code', 'fip']))

for i in range(valid_size):
  img, boxes = test_X[i], y_pred[i]

  img = boxes.draw_on_image(img, thickness=6)
  
  cv.imwrite('qr_code_fip_test_%d.png'%i, img[..., [2,1,0]])
  
# !rm qr_code_fip_test_resnet50.tar.gz test_results/*
# !mkdir test_results
# !mv qr_code_fip_test* test_results
# !tar -cvf qr_code_fip_test_resnet50.tar.gz test_results
# Out:
# Preprocessing Dataset: 100%|██████████| 593/593 [00:04<00:00, 126.15it/s]
# ppn_resnet50_qr_codes_fips.094-0.657357_mAP.hdf5
# Test mAP: [0.6414488439595656, 0.29264064618308394]
# mkdir: cannot create directory ‘test_results’: File exists
# test_results/
# test_results/qr_code_fip_test_74.png
# test_results/qr_code_fip_test_85.png
# test_results/qr_code_fip_test_50.png
# test_results/qr_code_fip_test_36.png
# test_results/qr_code_fip_test_42.png
# test_results/qr_code_fip_test_93.png
# test_results/qr_code_fip_test_32.png
# test_results/qr_code_fip_test_3.png
# test_results/qr_code_fip_test_35.png
# test_results/qr_code_fip_test_73.png
# test_results/qr_code_fip_test_29.png
# test_results/qr_code_fip_test_86.png
# test_results/qr_code_fip_test_81.png
# test_results/qr_code_fip_test_68.png
# test_results/qr_code_fip_test_95.png
# test_results/qr_code_fip_test_70.png
# test_results/qr_code_fip_test_80.png
# test_results/qr_code_fip_test_99.png
# test_results/qr_code_fip_test_77.png
# test_results/qr_code_fip_test_24.png
# test_results/qr_code_fip_test_72.png
# test_results/qr_code_fip_test_55.png
# test_results/qr_code_fip_test_8.png
# test_results/qr_code_fip_test_91.png
# test_results/qr_code_fip_test_5.png
# test_results/qr_code_fip_test_76.png
# test_results/qr_code_fip_test_79.png
# test_results/qr_code_fip_test_94.png
# test_results/qr_code_fip_test_26.png
# test_results/qr_code_fip_test_18.png
# test_results/qr_code_fip_test_51.png
# test_results/qr_code_fip_test_92.png
# test_results/qr_code_fip_test_38.png
# test_results/qr_code_fip_test_66.png
# test_results/qr_code_fip_test_19.png
# test_results/qr_code_fip_test_13.png
# test_results/qr_code_fip_test_87.png
# test_results/qr_code_fip_test_63.png
# test_results/qr_code_fip_test_48.png
# test_results/qr_code_fip_test_1.png
# test_results/qr_code_fip_test_71.png
# test_results/qr_code_fip_test_11.png
# test_results/qr_code_fip_test_37.png
# test_results/qr_code_fip_test_45.png
# test_results/qr_code_fip_test_7.png
# test_results/qr_code_fip_test_78.png
# test_results/qr_code_fip_test_22.png
# test_results/qr_code_fip_test_89.png
# test_results/qr_code_fip_test_62.png
# test_results/qr_code_fip_test_27.png
# test_results/qr_code_fip_test_90.png
# test_results/qr_code_fip_test_9.png
# test_results/qr_code_fip_test_53.png
# test_results/qr_code_fip_test_97.png
# test_results/qr_code_fip_test_34.png
# test_results/qr_code_fip_test_57.png
# test_results/qr_code_fip_test_47.png
# test_results/qr_code_fip_test_67.png
# test_results/qr_code_fip_test_54.png
# test_results/qr_code_fip_test_41.png
# test_results/qr_code_fip_test_17.png
# test_results/qr_code_fip_test_46.png
# test_results/qr_code_fip_test_49.png
# test_results/qr_code_fip_test_60.png
# test_results/qr_code_fip_test_14.png
# test_results/qr_code_fip_test_4.png
# test_results/qr_code_fip_test_30.png
# test_results/qr_code_fip_test_82.png
# test_results/qr_code_fip_test_39.png
# test_results/qr_code_fip_test_23.png
# test_results/qr_code_fip_test_15.png
# test_results/qr_code_fip_test_28.png
# test_results/qr_code_fip_test_0.png
# test_results/qr_code_fip_test_2.png
# test_results/qr_code_fip_test_61.png
# test_results/qr_code_fip_test_16.png
# test_results/qr_code_fip_test_88.png
# test_results/qr_code_fip_test_12.png
# test_results/qr_code_fip_test_98.png
# test_results/qr_code_fip_test_52.png
# test_results/qr_code_fip_test_58.png
# test_results/qr_code_fip_test_84.png
# test_results/qr_code_fip_test_44.png
# test_results/qr_code_fip_test_6.png
# test_results/qr_code_fip_test_65.png
# test_results/qr_code_fip_test_21.png
# test_results/qr_code_fip_test_10.png
# test_results/qr_code_fip_test_20.png
# test_results/qr_code_fip_test_59.png
# test_results/qr_code_fip_test_75.png
# test_results/qr_code_fip_test_40.png
# test_results/qr_code_fip_test_43.png
# test_results/qr_code_fip_test_25.png
# test_results/qr_code_fip_test_64.png
# test_results/qr_code_fip_test_96.png
# test_results/qr_code_fip_test_56.png
# test_results/qr_code_fip_test_83.png
# test_results/qr_code_fip_test_69.png
# test_results/qr_code_fip_test_33.png
# test_results/qr_code_fip_test_31.png
